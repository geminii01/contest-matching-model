# %%
from dotenv import load_dotenv
load_dotenv()

import os
import re
import csv
import json
import time
import numpy as np
import pandas as pd
from pprint import pprint
from tqdm import tqdm

from openai import OpenAI

from langchain import hub
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.prompts import PromptTemplate
from langchain_openai import OpenAIEmbeddings
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
OPENAI_API_KEY = os.environ.get('OPENAI_API_KEY')
OPENAI_ORG_KEY = os.environ.get('OPENAI_ORG_KEY')
UPSTAGE_API_KEY = os.environ.get('UPSTAGE_API_KEY')
LANGCHAIN_API_KEY = os.environ.get('LANGCHAIN_API_KEY')
# os.environ['LANGCHAIN_PROJECT'] = 'matching_model_EXP06' # 프로젝트명 수정
# os.environ['LANGCHAIN_TRACING_V2'] = 'true'
LANGCHAIN_PROJECT = os.environ.get('LANGCHAIN_PROJECT')

print(f'> LangSmith Project: {LANGCHAIN_PROJECT}')
# Out:
# > LangSmith Project: LangSmith에_표기할_프로젝트명

# %% [markdown]
# # 데이터 구성
#
# > 전처리, csv to jsonl

# %%
# 데이터 로드

text = pd.read_excel('../data/비식별된 해외기업별 영문 텍스트데이터.xlsx')
statis = pd.read_excel('../data/통계청 국제표준산업분류 HSCODE 6단위 매핑.xlsx')
customs = pd.read_excel('../data/관세청_HS부호_240101.xlsx')

text_copy = text.copy()
statis_copy = statis.copy()
customs_copy = customs.copy()

print('> 데이터 로드 완료')


# 데이터 전처리

def zero_input(num, x):
    if pd.isna(x):
        return np.nan
    else:
        cnt = num - len(x)
        return '0' * cnt + x
    
def re_sub(x):
    if pd.isna(x):
        return np.nan
    else:
        return re.sub(r'^\((.*?)\)$', r'\1', x)

text_copy['ID'] = text_copy['ID'].astype(str)
text_copy['CODE'] = text_copy['CODE'].astype(str)
text_copy['CODE'] = text_copy['CODE'].apply(lambda x: zero_input(4, x))

statis_copy.columns = [
    'ISIC4_CODE', # ISIC4_국제표준산업분류
    'ISIC4_NAME', # ISIC4_분류명
    'KSIC10_CODE', # KSIC10_한국표준산업분류
    'KSIC10_NAME', # KSIC10_분류명
    'HS2017_CODE', # HS2017_관세통계통합품목분류
    'HS2017_NAME' # HS2017_분류명
]

statis_copy['ISIC4_CODE'] = statis_copy['ISIC4_CODE'].astype(str)
statis_copy['ISIC4_CODE'] = statis_copy['ISIC4_CODE'].replace('nan', np.nan)
statis_copy['ISIC4_CODE'] = statis_copy['ISIC4_CODE'].str.replace('.0', '', regex=False)
statis_copy['ISIC4_CODE'] = statis_copy['ISIC4_CODE'].apply(lambda x: zero_input(4, x))

statis_copy['HS2017_CODE'] = statis_copy['HS2017_CODE'].astype(str)
statis_copy['HS2017_CODE'] = statis_copy['HS2017_CODE'].replace('nan', np.nan)
statis_copy['HS2017_CODE'] = statis_copy['HS2017_CODE'].str.replace('.0', '', regex=False)
statis_copy['HS2017_CODE'] = statis_copy['HS2017_CODE'].apply(lambda x: zero_input(6, x))

customs_copy.columns = [
    'HS_CODE', # HS부호
    'KOR_NAME', # 한글품목명
    'ENG_NAME', # 영문품목명
    'INT_CODE', # 성질통합분류코드
    'INT_NAME' # 성질통합분류명
]

customs_copy['HS_CODE'] = customs_copy['HS_CODE'].astype(str)
customs_copy['HS_CODE'] = customs_copy['HS_CODE'].apply(lambda x: zero_input(10, x))

customs_copy['INT_CODE'] = customs_copy['INT_CODE'].astype(str)
customs_copy['INT_CODE'] = customs_copy['INT_CODE'].replace('nan', np.nan)
customs_copy['INT_CODE'] = customs_copy['INT_CODE'].str.replace('.0', '', regex=False)

customs_copy['INT_NAME'] = customs_copy['INT_NAME'].apply(lambda x: re_sub(x))

text_copy = text_copy.fillna(' ')
statis_copy = statis_copy.fillna(' ')
customs_copy = customs_copy.fillna(' ')

print('> 데이터 전처리 완료')
print('> 데이터 결측치 확인')
print('-----' * 5)
print(text_copy.isnull().sum())
print(statis_copy.isnull().sum())
print(customs_copy.isnull().sum())
print('-----' * 5)


# 데이터 저장 및 로드

text_copy.to_csv('../data/prepro_text.csv', index=False, encoding='utf-8')
statis_copy.to_csv('../data/prepro_statis.csv', index=False, encoding='utf-8')
customs_copy.to_csv('../data/prepro_customs.csv', index=False, encoding='utf-8')

text_prepro = pd.read_csv('../data/prepro_text.csv', dtype=str)
statis_prepro = pd.read_csv('../data/prepro_statis.csv', dtype=str)
customs_prepro = pd.read_csv('../data/prepro_customs.csv', dtype=str)


# csv to jsonl

def csv_to_jsonl(csv_file_path, jsonl_file_path):
    with open(csv_file_path, mode='r', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        with open(jsonl_file_path, mode='w', encoding='utf-8') as jsonl_file:
            for row in csv_reader:
                jsonl_file.write(json.dumps(row, ensure_ascii=False) + '\n')

csv_to_jsonl('../data/prepro_text.csv', '../data/jsonl_prepro_text.jsonl')
csv_to_jsonl('../data/prepro_statis.csv', '../data/jsonl_prepro_statis.jsonl')
csv_to_jsonl('../data/prepro_customs.csv', '../data/jsonl_prepro_customs.jsonl')
print('> csv to jsonl 완료')
# Out:
# > 데이터 로드 완료
# > 데이터 전처리 완료
# > 데이터 결측치 확인
# -------------------------
# ID      0
# CODE    0
# DSC     0
# dtype: int64
# ISIC4_CODE     0
# ISIC4_NAME     0
# KSIC10_CODE    0
# KSIC10_NAME    0
# HS2017_CODE    0
# HS2017_NAME    0
# dtype: int64
# HS_CODE     0
# KOR_NAME    0
# ENG_NAME    0
# INT_CODE    0
# INT_NAME    0
# dtype: int64
# -------------------------
# > csv to jsonl 완료

# %% [markdown]
# # Document 구성

# %% [markdown]
# ## text

# %%
file_path = '../data/jsonl_prepro_text.jsonl'
temp = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        temp.append(json.loads(line.strip()))

seq_num = 1
text_documents = []
for data in temp:
    doc = Document(
        page_content=data['DSC'], 
        metadata={
            'ID': data['ID'],
            'CODE': data['CODE'],
            'source': '/root/contest-matching-model/data/jsonl_prepro_text.jsonl',
            'seq_num': seq_num,
        }
    )
    text_documents.append(doc)
    seq_num += 1

pprint(text_documents[0])
print(text_documents[0].page_content)
pprint(text_documents[0].metadata)
# Out:
# Document(page_content='automotive repair shops, nec  specialized automotive repair, not elsewhere classified, such as fuel service carburetor repair, brake relining, front-end and wheel alignment, and radiator repair. motor vehicle repair and maintenance auto brake lining, installation other automotive mechanical and electrical repair and maintenance maintenance and repair of motor vehicles maintenance and repair of motor vehicles maintenance and repair of motor vehiclesother automotive repair and maintenance', metadata={'ID': '1', 'CODE': '4520', 'source': '/root/contest-matching-model/data/jsonl_prepro_text.jsonl', 'seq_num': 1})
# automotive repair shops, nec  specialized automotive repair, not elsewhere classified, such as fuel service carburetor repair, brake relining, front-end and wheel alignment, and radiator repair. motor vehicle repair and maintenance auto brake lining, installation other automotive mechanical and electrical repair and maintenance maintenance and repair of motor vehicles maintenance and repair of motor vehicles maintenance and repair of motor vehiclesother automotive repair and maintenance
# {'CODE': '4520',
#  'ID': '1',
#  'seq_num': 1,
#  'source': '/root/contest-matching-model/data/jsonl_prepro_text.jsonl'}

# %% [markdown]
# ## statis

# %%
file_path = '../data/jsonl_prepro_statis.jsonl'
temp = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        temp.append(json.loads(line.strip()))

seq_num = 1
statis_documents = []
for data in temp:
    doc = Document(
        page_content=f"{data['ISIC4_NAME']}\r\n{data['KSIC10_NAME']}\r\n{data['HS2017_NAME']}", # ISIC4, KSIC10, HS2017 순으로 작성됨
        metadata={
            'ISIC4_CODE': data['ISIC4_CODE'],
            'KSIC10_CODE': data['KSIC10_CODE'],
            'HS2017_CODE': data['HS2017_CODE'],
            'source': '/root/contest-matching-model/data/jsonl_prepro_statis.jsonl',
            'seq_num': seq_num,
        }
    )
    statis_documents.append(doc)
    seq_num += 1

pprint(statis_documents[0])
print(statis_documents[0].page_content)
pprint(statis_documents[0].metadata)
# Out:
# Document(page_content='곡물(쌀 제외), 콩류, 종실유 재배업\r\n종자 및 묘목 생산업\r\n종자', metadata={'ISIC4_CODE': '0111', 'KSIC10_CODE': '01123', 'HS2017_CODE': '100111', 'source': '/root/contest-matching-model/data/jsonl_prepro_statis.jsonl', 'seq_num': 1})
# 곡물(쌀 제외), 콩류, 종실유 재배업
# 종자 및 묘목 생산업
# 종자
# {'HS2017_CODE': '100111',
#  'ISIC4_CODE': '0111',
#  'KSIC10_CODE': '01123',
#  'seq_num': 1,
#  'source': '/root/contest-matching-model/data/jsonl_prepro_statis.jsonl'}

# %% [markdown]
# ## customs

# %%
file_path = '../data/jsonl_prepro_customs.jsonl'
temp = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        temp.append(json.loads(line.strip()))

seq_num = 1
customs_documents = []
for data in temp:
    doc = Document(
        page_content=f"{data['KOR_NAME']}\r\n{data['ENG_NAME']}\r\n{data['INT_NAME']}", # 한글품목명, 영어품목명, 성질 통합 분류명 순으로 작성됨
        metadata={
            'HS_CODE': data['HS_CODE'],
            'INT_CODE': data['INT_CODE'],
            'source': '/root/contest-matching-model/data/jsonl_prepro_customs.jsonl',
            'seq_num': seq_num,
        }
    )
    customs_documents.append(doc)
    seq_num += 1

pprint(customs_documents[0])
print(customs_documents[0].page_content)
pprint(customs_documents[0].metadata)
# Out:
# Document(page_content='농가 사육용\r\nFor farm breeding\r\n말', metadata={'HS_CODE': '0101211000', 'INT_CODE': '11020101', 'source': '/root/contest-matching-model/data/jsonl_prepro_customs.jsonl', 'seq_num': 1})
# 농가 사육용
# For farm breeding
# 말
# {'HS_CODE': '0101211000',
#  'INT_CODE': '11020101',
#  'seq_num': 1,
#  'source': '/root/contest-matching-model/data/jsonl_prepro_customs.jsonl'}

# %% [markdown]
# # OpenAI Summarization + Translation

# %%
text_dup = text_prepro.drop_duplicates(subset='DSC').reset_index(drop=True)
text_dup
# Out:
#          ID  CODE                                                DSC
# 0         1  4520  automotive repair shops, nec  specialized auto...
# 1         2  0149  general farms, primarily animals, nsk  derives...
# 2         3  4630  fish and seafoods  the wholesale distribution ...
# 3         4  4510  new and used car dealers, nsk  manufactures a ...
# 4         4  2930  automotive stampings, nsk  manufacturing autom...
# ...     ...   ...                                                ...
# 1713  10634  4669  printing and writing paper, nsk  the wholesale...
# 1714  10635  1410  leather and sheep-lined clothing  manufacturin...
# 1715  10636  4652  electronic parts and equipment, nec, nsk  the ...
# 1716  10642  1104  bottled and canned soft drinks, nsk  manufactu...
# 1717  10644  2410  blast furnaces and steel mills, nsk  manufactu...
#
# [1718 rows x 3 columns]

# %%
def summary_prompt(text):
    prompt = (
        "Please summarize the following English text, ensuring that the summary captures the main points and key information from the original text:\n\n"
        "{text}\n\n"
        "Then translate the summary into Korean.\n\n"
        "Desired output format:\n"
        "Summary: <English summary>\n"
        "Korean: <Korean translation>"
    )
    return prompt.format(text=text)

def get_summary(text):
    prompt = summary_prompt(text=text)
    completion = client.chat.completions.create(
        model='gpt-3.5-turbo-0125',
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        temperature=0
    )
    return completion.choices[0].message.content

client = OpenAI(
    api_key=OPENAI_API_KEY,
    organization=OPENAI_ORG_KEY
)

file_path = '../data/jsonl_summary_text.jsonl'
with open(file_path, 'a', encoding='utf-8') as file:
    for idx in range(text_dup.shape[0]):
        text = text_dup.loc[idx, 'DSC']
        response = get_summary(text=text)

        output = {
            "ID": text_dup.loc[idx, 'ID'], 
            "CODE": text_dup.loc[idx, 'CODE'], 
            "DSC": response
        }
        file.write(f'{json.dumps(output, ensure_ascii=False)}\n')

        print('-----' * 7)
        print(f'{idx}.\nOrginal: {text}\n{response}')
# Out:
# -----------------------------------
# 0.
# Orginal: automotive repair shops, nec  specialized automotive repair, not elsewhere classified, such as fuel service carburetor repair, brake relining, front-end and wheel alignment, and radiator repair. motor vehicle repair and maintenance auto brake lining, installation other automotive mechanical and electrical repair and maintenance maintenance and repair of motor vehicles maintenance and repair of motor vehicles maintenance and repair of motor vehiclesother automotive repair and maintenance
# Summary: The text describes various specialized automotive repair services such as fuel service, carburetor repair, brake relining, wheel alignment, and radiator repair, as well as general motor vehicle repair and maintenance.
#
# Korean: 이 텍스트는 연료 서비스, 기화기 수리, 브레이크 재설치, 휠 정렬 및 라디에이터 수리와 같은 다양한 특수 자동차 수리 서비스와 일반 자동차 수리 및 유지보수에 대해 설명하고 있습니다.
# -----------------------------------
# 1.
# Orginal: general farms, primarily animals, nsk  derives 50 percent or more of its total value  of sales of agricultural products from livestock and animal specialties and their products, but less than 50 percent from products of any single three-digit industry group. crop and animal production general farms, primarily animals all other animal production mixed farming raising of other animals mixed farmingother livestock farming not elsewhere classified
# Summary: The text describes general farms that primarily focus on animal production, deriving over 50% of their sales value from livestock and animal products. These farms engage in a variety of agricultural activities, including crop production and raising different types of animals.
#
# Korean: 이 텍스트는 주로 가축 생산에 중점을 둔 일반 농장을 설명하며, 이러한 농장들이 가축 및 동물 제품에서 판매 가치의 50% 이상을 창출한다고 설명합니다. 이러한 농장들은 작물 생산과 다양한 종류의 동물을 기르는 등 다양한 농업 활동을 수행합니다.
# -----------------------------------
# 2.
# Orginal: fish and seafoods  the wholesale distribution but not packaging of fresh, cured, or frozen fish and seafoods, except canned or packaged frozen. grocery wholesale seafoods fish and seafood merchant wholesalers wholesale of other food, including fish, crustaceans and molluscs wholesale of food, beverages and tobacco wholesale of other food, including fish, crustaceans and molluscsfish and seafood wholesaling
# Summary: The text discusses the wholesale distribution of fish and seafood, excluding canned or packaged frozen products. It also mentions the wholesale of other food items, including fish, crustaceans, and molluscs.
#
# Korean: 이 텍스트는 살아 있는, 처리된 또는 냉동된 생선과 해산물의 도매 유통에 대해 다루고 있으며, 캔이나 포장된 냉동 제품은 제외됩니다. 또한 생선, 갑각류 및 연체동물을 포함한 다른 식품의 도매와 관련된 내용을 언급하고 있습니다.
# -----------------------------------
# 3.
# Orginal: new and used car dealers, nsk  manufactures a range of vehicles under its fiat and chrysler brands, including jeep, ram, dodge, alfa romeo, and abarth at 45 plants in the us and mexico. it ships about 2.5 million vehicles every year. it also features its parent's trademarked mopar motor parts automobile parts and service brand which carries more than 500,000 parts, options, and accessories for vehicle customization. motor vehicle and parts dealers automobiles, new and used new car dealers sale of cars and light motor vehicles sale of motor vehicles sale of cars and light motor vehiclesmotor vehicle retailing
# Summary: The company manufactures vehicles under Fiat and Chrysler brands, including Jeep, Ram, Dodge, Alfa Romeo, and Abarth at multiple plants in the US and Mexico. It ships around 2.5 million vehicles annually and offers a wide range of automobile parts and services under the Mopar brand.
#
# Korean: 회사는 미국과 멕시코의 다수 공장에서 피아트와 크라이슬러 브랜드를 통해 자동차를 생산하며, 매년 약 250만 대의 차량을 선적합니다. 또한 Mopar 브랜드 아래 다양한 자동차 부품과 서비스를 제공합니다.
# -----------------------------------
# 4.
# Orginal: automotive stampings, nsk  manufacturing automotive stampings, such as body parts, hubs, and trim. motor vehicle parts manufacturing automotive stampings motor vehicle metal stamping forging, pressing, stamping and roll-forming of metal; powder metallurgy manufacture of parts and accessories for motor vehicles forging, pressing, stamping and roll-forming of metal; powder metallurgysheet metal product manufacturing (except metal structural and container products)
# Summary: The text discusses the manufacturing of automotive stampings, including body parts, hubs, and trim, as well as the production of motor vehicle parts through processes like forging, pressing, and roll-forming of metal.
#
# Korean: 요약: 이 텍스트는 차량 부품인 바디 부품, 허브 및 트림을 비롯한 자동차 스탬핑의 제조에 대해 다루며, 금속을 단조, 압출 및 롤 형성하는 공정을 통해 자동차 부품을 생산하는 내용을 다룹니다.
# -----------------------------------
# 5.
# Orginal: furniture stores  the retail sale of household furniture. these stores may also sell home furnishings, major appliances, and floor coverings. home furnishings retail furniture stores furniture stores retail sale of furniture, lighting equipment and other household articles (other than musical instruments) n.e.c., in specialised stores retail sale of electrical household appliances, furniture, lighting equipment and other household articles in specialized stores retail sale of furniture, lighting equipment and other household articles in specialised storesfurniture retailing
# Summary: Furniture stores primarily sell household furniture, home furnishings, major appliances, and floor coverings. They may also offer lighting equipment and other household articles in specialized stores.
#
# Korean: 가구 매장은 주로 가정용 가구, 가정용 가구, 대형 가전제품 및 바닥재 등을 판매합니다. 그들은 전문 매장에서 조명 장비 및 기타 가정 용품도 제공할 수 있습니다.
# -----------------------------------
# 6.
# Orginal: industrial machinery and equipment  the wholesale distribution of industrial machinery and equipment, not elsewhere classified. machinery wholesale industrial machinery and equipment industrial machinery and equipment merchant wholesalers wholesale of other machinery and equipment wholesale of other machinery and equipment wholesale of other machinery, equipment and suppliesother specialised industrial machinery and equipment wholesaling
# Summary: The text discusses the wholesale distribution of industrial machinery and equipment, including other specialized machinery and equipment.
#
# Korean: 이 텍스트는 산업용 기계 및 장비의 도매 유통에 대해 다루며, 다른 특수화된 기계 및 장비를 포함합니다.
# -----------------------------------
# 7.
# Orginal: metal cans, nsk  manufacturing metal cans from purchased materials. metal products manufacturing food and beverage containers metal can manufacturing manufacture of light metal packaging manufacture of other fabricated metal products n.e.c. manufacture of light metal packagingother metal container manufacturing
# Summary: The text describes the manufacturing of metal cans for food and beverage containers, light metal packaging, and other fabricated metal products.
#
# Korean: 이 텍스트는 음식 및 음료용 캔, 경량 금속 포장재, 그리고 기타 가공된 금속 제품을 제조하는 과정을 설명하고 있습니다.
# -----------------------------------
# 8.
# Orginal: sporting and athletic goods, nec the coleman company makes what it takes to be a happy camper. as a leading manufacturer of outdoor recreation gear, it produces coolers, backpacks, tents, sleeping bags, air mattresses, lanterns, grills, life vests, and floats, among other items, which are sold under the wake vest, helium, puddle jumper, mad dog gear, sevylor, and stearns brands. coleman operates sales offices and distribution facilities worldwide and sells its products mainly through mass merchandisers, home centers, and other retail stores, as well as through its website and a network of about a dozen coleman factory outlet stores. founded in 1900, coleman is owned by jarden corporation. miscellaneous manufacturing camping equipment and supplies sporting and athletic goods manufacturing manufacture of sports goods manufacture of sports goods manufacture of sports goodstoy, sporting and recreational product manufacturing
# Summary: The Coleman Company is a leading manufacturer of outdoor recreation gear, producing a variety of products such as coolers, tents, sleeping bags, and lanterns under different brand names. It sells its products globally through various retail channels and is owned by Jarden Corporation.
#
# Korean: 콜맨 컴퍼니는 아웃도어 레크리에이션 장비의 선두 제조업체로, 쿨러, 텐트, 침낭, 등의 다양한 제품을 다양한 브랜드로 생산합니다. 제이든 코퍼레이션 소유로, 다양한 소매 채널을 통해 제품을 전 세계적으로 판매하고 있습니다.
# -----------------------------------
# 9.
# Orginal: power-driven handtools, nsk  create a lot of buzz. the company, which is the us arm of germany-based stihl international, makes chainsaws, edgers, leaf blowers, trimmers, and other landscaping tools and components. stihl incorporated markets its products, which are protected by more than 1,000 patents, through a dozen corporate distribution centers and independent wholesalers. its tools are sold by more than 9,000 independent tool and hardware retailers you won't find them at big box home stores throughout the us and exported to more than 90 countries. the us-based marketing and manufacturing unit was established in 1974. machinery and equipment manufacturing chain saws, portable power-driven handtool manufacturing manufacture of power-driven hand tools manufacture of power-driven hand tools manufacture of power-driven hand toolsmachine tool and parts manufacturing
# Summary: Stihl Incorporated, the US arm of Germany-based Stihl International, produces power-driven hand tools such as chainsaws, edgers, leaf blowers, and trimmers. Their products are distributed through corporate centers and wholesalers, not big box stores, and are sold in over 90 countries.
#
# Korean: 스틸 인코포레이티드는 독일 스틸 인터내셔널의 미국 지사로, 전기 구동 핸드툴인 전기톱, 에지, 리프 블로어, 트리머 등을 생산합니다. 제품은 기업 센터와 독립 도매업자를 통해 유통되며 대형 박스 매장이 아닌 90개국 이상에서 판매됩니다.
# -----------------------------------
# 10.
# Orginal: fresh fruits and vegetables  the wholesale distribution of fresh fruits and vegetables. grocery wholesale fruits, fresh fresh fruit and vegetable merchant wholesalers wholesale of fruit and vegetables wholesale of food, beverages and tobacco wholesale of fruit and vegetablesfruit and vegetable wholesaling
# Summary: The text discusses the wholesale distribution of fresh fruits and vegetables, focusing on merchant wholesalers who specialize in selling these products in bulk.
#
# Korean: 이 텍스트는 신선한 과일과 채소의 도매 유통에 대해 다루며, 이러한 제품을 대량으로 판매하는 상인 도매업자에 초점을 맞추고 있습니다.
# -----------------------------------
# 11.
# Orginal: motor vehicle supplies and new parts  the wholesale distribution of motor vehicle supplies, accessories, tools, and equipment; and new motor vehicle parts. motor vehicle wholesale automotive supplies and parts motor vehicle supplies and new parts merchant wholesalers wholesale trade of motor vehicle parts and accessories sale of motor vehicle parts and accessories wholesale trade of motor vehicle parts and accessoriesmotor vehicle new parts wholesaling
# Summary: The text discusses the wholesale distribution of motor vehicle supplies, accessories, tools, equipment, and new parts.
#
# Korean: 이 텍스트는 자동차 용품, 액세서리, 도구, 장비 및 새 자동차 부품의 도매 유통에 대해 논의합니다.
# -----------------------------------
# 12.
# Orginal: chemicals and allied products, nec  the wholesale distribution of chemicals and allied products, not elsewhere classified, such as acids, industrial and heavy chemicals, dyestuffs, industrial salts, rosin, and turpentine. chemical wholesale detergents other chemical and allied products merchant wholesalers wholesale of chemical products wholesale of waste and scrap and other products n.e.c. wholesale of chemical productsindustrial and agricultural chemical product wholesaling
# Summary: The text describes the wholesale distribution of various chemicals and allied products, including acids, industrial chemicals, dyestuffs, salts, rosin, and turpentine. It also mentions the wholesale of detergents, waste, scrap, and other chemical products not elsewhere classified.
#
# Korean: 이 텍스트는 산업 화학제품, 염료, 염료, 산업용 소금, 로신 및 텔프틴과 같은 다양한 화학물질 및 관련 제품의 도매 유통을 설명하며, 세제, 폐기물, 스크랩 및 기타 분류되지 않은 화학 제품의 도매도 언급합니다.
# -----------------------------------
# 13.
# Orginal: electronic parts and equipment, nec, nsk  the wholesale distribution of electronic parts and electronic communications equipment, not elsewhere classified, such as telephone and telegraphic equipment; radio and television broadcasting and communications equipment; and intercommunications equipment. electronics wholesale electronic parts and equipment, nec other electronic parts and equipment merchant wholesalers wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and partsother electrical and electronic goods wholesaling
# Summary: The text describes the wholesale distribution of various electronic parts and equipment, including telecommunications equipment, broadcasting equipment, and intercommunications equipment.
#
# Korean: 이 텍스트는 전자 부품 및 장비의 도매 유통을 설명하며, 전화 및 전신 장비, 라디오 및 텔레비전 방송 및 통신 장비, 상호 통신 장비 등이 포함됩니다.
# -----------------------------------
# 14.
# Orginal: misc. apparel and accessory stores,nsk  the retail sale of specialized lines of apparel and accessories, not elsewhere classified, such as uniforms, bathing suits, raincoats, riding apparel, sports apparel, umbrellas, wigs, and toupees. this industry also includes custom tailors primarily engaged in making and selling men's and women's clothing, except fur apparel. clothing and apparel stores uniforms other clothing stores retail sale of clothing in specialised stores retail sale of clothing, footwear and leather articles in specialized stores retail sale of clothing in specialised storesother personal accessory retailing
# Summary: The text describes the retail sale of specialized apparel and accessories in miscellaneous stores, including items such as uniforms, bathing suits, raincoats, sports apparel, and wigs. It also includes custom tailors selling men's and women's clothing, excluding fur apparel.
#
# Korean: 이 텍스트는 일반 의류 및 액세서리 매장에서 특수 의류 및 액세서리의 소매 판매를 설명하며, 유니폼, 수영복, 우비, 스포츠 의류, 가발 등을 포함합니다. 또한 모피 의류를 제외한 남성 및 여성 의류를 판매하는 맞춤 테일러도 포함됩니다.
# -----------------------------------
# 15.
# Orginal: meat packing plants, nsk  the slaughtering, for their own account or on a contract basis for the trade, of cattle, hogs, sheep, lambs, and calves for meat to be sold or to be used on the same premises in canning, cooking, curing, and freezing, and in making sausage, lard, and other products. this includes slaughtering horses for human consumption. food manufacturing meat by-products, from meat slaughtered on site animal (except poultry) slaughtering processing and preserving of meat processing and preserving of meat processing and preserving of meat and production of meat productsmeat processing
# Summary: The text describes the activities of meat packing plants, including slaughtering animals for meat production, processing and preserving meat, and producing meat products.
#
# Korean: 요약: 이 텍스트는 고기 가공 공장의 활동을 설명하며, 고기 생산을 위해 동물을 도축하고, 고기를 가공 및 보존하며, 고기 제품을 생산하는 내용을 다룹니다.
# -----------------------------------
# 16.
# Orginal: poultry hatcheries, nsk  operating poultry hatcheries on their own account or on a contract or fee basis. crop and animal production poultry hatcheries, nec poultry hatcheries raising of poultry raising of poultry raising of poultrypoultry farming (meat)
# Summary: The text discusses poultry hatcheries, including those operating independently or on a contract basis. It also mentions the raising of poultry for meat production.
#
# Korean: 이 텍스트는 독립적으로 운영되거나 계약 기반으로 운영되는 가금류 부화장에 대해 논의하며, 고기 생산을 위해 가금류를 양육하는 것도 언급하고 있습니다.
# -----------------------------------
# 17.
# Orginal: groceries, general line, nsk  the wholesale distribution of a general line of groceries. grocery wholesale food brokers general line grocery merchant wholesalers non-specialised wholesale of food, beverages and tobacco wholesale of food, beverages and tobacco wholesale of food, beverages and tobaccogeneral line grocery wholesaling
# Summary: The text describes the wholesale distribution of a general line of groceries, including food, beverages, and tobacco.
#
# Korean: 텍스트는 식료품, 음료 및 담배를 포함한 종합식료품의 도매 유통에 대해 설명합니다.
# -----------------------------------
# 18.
# Orginal: poultry hatcheries, nsk  operating poultry hatcheries on their own account or on a contract or fee basis. crop and animal production chicken hatchery poultry hatcheries raising of poultry raising of poultry raising of poultrypoultry farming (meat)
# Summary: The text discusses poultry hatcheries that operate independently or on a contract basis for chicken and poultry farming.
#
# Korean: 이 텍스트는 독립적으로 또는 계약 기반으로 닭과 가금류 농장을 운영하는 가금류 부화장에 대해 논의합니다.
# -----------------------------------
# 19.
# Orginal: nondurable goods, nec, nsk  the wholesale distribution of non-durable goods, not elsewhere classified, such as art goods, industrial yarns, textile bags, and bagging and burlap. nonclassifiable establishments general merchandise, non-durable other miscellaneous nondurable goods merchant wholesalers nonclassifiable establishments non-specialized wholesale trade non-specialised wholesale tradenonclassifiable establishments
# Summary: The text describes the wholesale distribution of non-durable goods, including art goods, industrial yarns, textile bags, and burlap, under various classifications.
#
# Korean: 이 텍스트는 다양한 분류로 예술용품, 산업용 실, 직물 가방 및 벌랍 등을 포함한 비내구재의 도매 유통을 설명합니다.
# -----------------------------------
# 20.
# Orginal: industrial machinery and equipment  the wholesale distribution of industrial machinery and equipment, not elsewhere classified. machinery wholesale industrial machine parts industrial machinery and equipment merchant wholesalers wholesale of other machinery and equipment wholesale of other machinery and equipment wholesale of other machinery, equipment and suppliesother specialised industrial machinery and equipment wholesaling
# Summary: The text describes the wholesale distribution of industrial machinery and equipment, including machine parts and specialized equipment.
#
# Korean: 이 텍스트는 산업용 기계 및 장비, 기계 부품 및 특수 장비를 도매 유통하는 것에 대해 설명하고 있습니다.
# -----------------------------------
# 21.
# Orginal: packaged frozen goods  the wholesale distribution of packaged quick-frozen vegetables, juices, meats, fish, poultry, pastries, and other "deep freeze" products. grocery wholesale meat, frozen: packaged packaged frozen food merchant wholesalers non-specialised wholesale of food, beverages and tobacco wholesale of food, beverages and tobacco wholesale of food, beverages and tobaccoother grocery wholesaling
# Summary: The text discusses wholesale distribution of various packaged frozen goods such as vegetables, meats, fish, pastries, and other food products.
#
# Korean: 이 텍스트는 채소, 고기, 생선, 빵과 같은 다양한 포장 냉동 식품의 도매 유통에 대해 다루고 있습니다.
# -----------------------------------
# 22.
# Orginal: eating places filipinos looking to get their fast-food jollies can turn to this happy bee. jollibee foods is the leading operator of quick-service restaurants in the philippines, with more than 1,500 outlets encompassing about a half dozen different concepts. its flagship jollibee chain features a menu of fast-food staples hamburgers, hot dogs, and fried chicken along with asian spring rolls, spaghetti, soups, and ice cream. the company also operates such chains as greenwich pizza, chowking and yonghe king quick-service asian food, and red ribbon bakery items.?in addition to its domestic operations, jollibee has restaurants in about six other countries. restaurants and bars fast-food restaurant, chain limited-service restaurants restaurants and mobile food service activities restaurants and mobile food service activities restaurants and mobile food service activitiescafes, restaurants and takeaway food services
# Summary: Jollibee Foods is a leading operator of quick-service restaurants in the Philippines, with over 1,500 outlets offering various fast-food concepts including hamburgers, hot dogs, fried chicken, Asian spring rolls, spaghetti, soups, and ice cream. They also have chains like Greenwich Pizza, Chowking, Yonghe King, and Red Ribbon Bakery.
#
# Korean: 요리 장소 필리핀 사람들은 이 행복한 벌에게 빠른 음식을 찾을 수 있습니다. Jollibee Foods는 필리핀에서 빠른 음식 레스토랑을 운영하는 선두 기업으로, 햄버거, 핫도그, 후라이드 치킨, 아시아식 롤, 스파게티, 수프, 아이스크림 등 다양한 패스트푸드 개념을 제공하는 1,500개 이상의 지점을 보유하고 있습니다. 또한, Greenwich Pizza, Chowking, Yonghe King, Red Ribbon Bakery와 같은 체인을 운영하고 있습니다.
# -----------------------------------
# 23.
# Orginal: general government, nec, nsk  providing general support for government, which include personnel, auditing, procurement services, and building management services, and other general government establishments which cannot be classified in other industries. executive and legislature general government, nec other general government support general public administration activities general public administration activities general public administration activitiespublic administration
# Summary: The text describes general government support services such as personnel, auditing, procurement, and building management for executive and legislative branches. It also includes public administration activities that do not fall under specific industries.
#
# Korean: 이 텍스트는 행정부와 입법부를 위한 인사, 감사, 구매 및 건물 관리와 같은 일반 정부 지원 서비스를 설명하며, 특정 산업에 속하지 않는 공공 행정 활동을 포함합니다.
# -----------------------------------
# 24.
# Orginal: meats and meat products, nsk  the wholesale distribution of fresh, cured, and processed but not canned meats and lard. grocery wholesale meats and meat products meat and meat product merchant wholesalers wholesale of meat and meat products wholesale of food, beverages and tobacco wholesale of meat and meat productsmeat, poultry and smallgoods wholesaling
# Summary: The text discusses the wholesale distribution of various types of meats and meat products, including fresh, cured, and processed meats, but not canned meats and lard. It also mentions the wholesale of food, beverages, and tobacco, specifically focusing on meat, poultry, and smallgoods wholesaling.
#
# Korean: 이 텍스트는 신선한, 염제된, 가공된 고기 및 육류 제품의 도매 유통에 대해 다루고 있으며, 캔 고기와 돼지 기름은 포함되지 않습니다. 또한 식품, 음료 및 담배의 도매에 대해 언급하며, 특히 고기, 가금류 및 소품 도매에 초점을 맞추고 있습니다.
# -----------------------------------
# 25.
# Orginal: groceries and related products, nec, nsk  the wholesale distribution of soft drinks, and in bottling and distributing natural spring and mineral waters, are classified in this industry. grocery wholesale groceries and related products, nec other grocery and related products merchant wholesalers wholesale of other food, including fish, crustaceans and molluscs wholesale of food, beverages and tobacco wholesale of food, beverages and tobaccoother grocery wholesaling
# Summary: This text describes the classification and activities within the wholesale industry related to groceries, soft drinks, natural spring and mineral waters, and other food products including fish and beverages.
#
# Korean: 이 텍스트는 식료품, 음료수, 천연 샘물 및 광물수, 그리고 생선, 갑각류 및 연체류를 포함한 다른 식품에 대한 도매 산업의 분류 및 활동을 설명합니다.
# -----------------------------------
# 26.
# Orginal: groceries and related products, nec, nsk  the wholesale distribution of soft drinks, and in bottling and distributing natural spring and mineral waters, are classified in this industry. grocery wholesale canned goods: fruit, vegetables, seafood, meats, etc. other grocery and related products merchant wholesalers wholesale of other food, including fish, crustaceans and molluscs wholesale of food, beverages and tobacco wholesale of food, beverages and tobaccoother grocery wholesaling
# Summary: This industry involves wholesale distribution of soft drinks, bottling and distributing natural spring and mineral waters, as well as wholesale of various groceries including canned goods, fruits, vegetables, seafood, meats, and other food products like fish and beverages.
#
# Korean: 이 산업은 소프트 드링크의 도매 유통, 천연 샘물 및 광물수의 병입 및 유통, 그리고 통조림, 과일, 채소, 해산물, 고기 등의 식료품 및 다른 식품 상품인 생선과 음료수 등의 도매를 포함합니다.
# -----------------------------------
# 27.
# Orginal: fish and seafoods  the wholesale distribution but not packaging of fresh, cured, or frozen fish and seafoods, except canned or packaged frozen. grocery wholesale fish and seafoods fish and seafood merchant wholesalers wholesale of other food, including fish, crustaceans and molluscs wholesale of food, beverages and tobacco wholesale of other food, including fish, crustaceans and molluscsfish and seafood wholesaling
# Summary: The text discusses the wholesale distribution of fish and seafood, excluding canned or packaged frozen products. It also mentions the wholesale of other food items, including fish, crustaceans, and molluscs.
#
# Korean: 이 텍스트는 살아 있는 또는 냉동된 생선과 해산물의 도매 유통에 대해 다루며, 캔이나 포장된 냉동 제품은 제외됩니다. 또한 생선, 갑각류 및 연체동물을 포함한 다른 식품의 도매에 대해 언급합니다.
# -----------------------------------
# 28.
# Orginal: sausages and other prepared meats  manufacturing sausages, cured meats, smoked meats, canned meats, frozen meats, and other prepared meats and meat specialties, from purchased carcasses and other materials. prepared meat plants operated by packing houses as separate establishments are also included in this industry. food manufacturing pork, cured: from purchased meat meat processed from carcasses production of meat and poultry meat products processing and preserving of meat production of meat and poultry meat productsmeat processing
# Summary: The text describes the manufacturing process of sausages and other prepared meats, including cured meats, smoked meats, canned meats, frozen meats, and meat specialties. It also mentions that prepared meat plants operated by packing houses are included in this industry.
#
# Korean: 이 텍스트는 소시지 및 기타 가공 육류, 소금냠, 훈제 육류, 통조림 육류, 냉동 육류 및 기타 가공 육류 및 육류 특산품의 제조 과정을 설명하며, 포장 공장에서 운영되는 가공 육류 공장도 이 산업에 포함된다고 언급합니다.
# -----------------------------------
# 29.
# Orginal: new and used car dealers, nsk  the retail sale of new automobiles or new and used automobiles. these establishments frequently maintain repair departments and carry stocks of replacement parts, tires, batteries, and automotive accessories. these establishments also frequently sell pickups and vans at retail. motor vehicle and parts dealers new and used car dealers new car dealers sale of cars and light motor vehicles sale of motor vehicles sale of cars and light motor vehiclesmotor vehicle retailing
# Summary: The text describes new and used car dealerships that sell new automobiles, used automobiles, pickups, vans, and automotive accessories. These establishments also offer repair services and stock replacement parts, tires, and batteries.
#
# Korean: 이 텍스트는 새 자동차 및 중고 자동차를 판매하는 자동차 딜러쉽에 대해 설명하며, 이들은 수리 서비스를 제공하고 교체 부품, 타이어, 배터리 및 자동차 액세서리를 보유하고 있습니다.
# -----------------------------------
# 30.
# Orginal: motor vehicles and car bodies  manufacturing or assembling complete passenger automobiles, trucks, commercial cars and buses, and special purpose motor vehicles which are for highway use. this also includes the manufacturing of chassis and passenger car bodies. motor vehicle manufacturing motor vehicles and car bodies automobile manufacturing manufacture of motor vehicles manufacture of motor vehicles manufacture of motor vehicles, trailers and semi-trailersmotor vehicle and motor vehicle part manufacturing
# Summary: The text discusses the manufacturing or assembling of motor vehicles, car bodies, passenger automobiles, trucks, commercial cars, buses, and special purpose motor vehicles for highway use, including chassis and passenger car bodies.
#
# Korean: 이 텍스트는 자동차, 차체, 승용차, 트럭, 상용차, 버스 및 고속도로용 특수 목적 자동차의 제조 또는 조립, 샤시 및 승용차 본체 제조에 대해 논의합니다.
# -----------------------------------
# 31.
# Orginal: instruments to measure electricity  manufacturing instruments for measuring the characteristics of electricity and electrical signals, such as voltmeters, ammeters, wattmeters, watt-hour meters, demand meters, and equipment for testing the electrical characteristics of electrical, radio, and communication circuits and of internal combustion engines. electromedical and control instruments manufacturing electrical energy measuring equipment instrument manufacturing for measuring and testing electricity and electrical signals manufacture of electronic instruments and appliances for measuring, testing, and navigation, except industrial process control equipment manufacture of measuring, testing, navigating and control equipment manufacture of instruments and appliances for measuring, testing and navigationother professional and scientific equipment manufacturing
# Summary: The text discusses the manufacturing of various instruments to measure electricity, including voltmeters, ammeters, wattmeters, and equipment for testing electrical characteristics in different applications such as electromedical, control, and electronic instruments.
#
# Korean: 요약: 이 텍스트는 전압계, 전류계, 와트계 등 전기를 측정하는 다양한 기기를 제조하는 것에 대해 다루고 있으며, 전기 의료, 제어 및 전자 기기에서 전기 특성을 테스트하는 장비를 포함합니다.
# -----------------------------------
# 32.
# Orginal: surgical and medical instruments  manufacturing medical, surgical, ophthalmic, and veterinary instruments and apparatus. medical equipment and supplies surgical and medical instruments surgical and medical instrument manufacturing manufacture of medical and dental instruments and supplies manufacture of medical and dental instruments and supplies manufacture of medical and dental instruments and suppliesmedical and surgical equipment manufacturing
# Summary: The text discusses the manufacturing of medical, surgical, ophthalmic, and veterinary instruments and apparatus, as well as medical equipment and supplies.
#
# Korean: 이 텍스트는 의료, 수술, 안과 및 수의학 기구 및 기구의 제조, 그리고 의료 장비 및 용품에 대해 다룹니다.
# -----------------------------------
# 33.
# Orginal: pharmaceutical preparations : 1 manufacturing bulk organic and inorganic medicinal chemicals and their derivatives and 2 processing grading, grinding, and milling bulk botanical drugs and herbs. this also includes manufacturing agar-agar and similar products of natural origin, endocrine products, manufacturing or isolating basic vitamins, and isolating active medicinal principals such as alkaloids from botanical drugs and herbs. pharmaceutical manufacturing medicinals and botanicals medicinal and botanical manufacturing manufacture of basic pharmaceutical products manufacture of pharmaceuticals, medicinal chemical and botanical products manufacture of basic pharmaceutical productshuman pharmaceutical and medicinal product manufacturing
# Summary: The text discusses the manufacturing processes involved in producing pharmaceutical preparations, including bulk organic and inorganic chemicals, botanical drugs and herbs, agar-agar, endocrine products, vitamins, and medicinal principals like alkaloids.
#
# Korean: 이 텍스트는 제약 제품을 생산하는 제조 과정에 대해 다루며, 대량의 유기 및 무기 화학물질, 식물성 약물 및 허브, 아가르 아가르, 내분비 제품, 비타민, 알칼로이드와 같은 약물 주요 성분을 생산하는 과정을 다룹니다.
# -----------------------------------
# 34.
# Orginal: medicinals and botanicals, nsk : 1 manufacturing bulk organic and inorganic medicinal chemicals and their derivatives and 2 processing grading, grinding, and milling bulk botanical drugs and herbs. this also includes manufacturing agar-agar and similar products of natural origin, endocrine products, manufacturing or isolating basic vitamins, and isolating active medicinal principals such as alkaloids from botanical drugs and herbs. pharmaceutical manufacturing penicillin: bulk, uncompounded medicinal and botanical manufacturing manufacture of basic pharmaceutical products manufacture of pharmaceuticals, medicinal chemical and botanical products manufacture of basic pharmaceutical productshuman pharmaceutical and medicinal product manufacturing
# Summary: The text describes the manufacturing and processing activities related to medicinal and botanical products, including organic and inorganic chemicals, bulk botanical drugs and herbs, agar-agar, endocrine products, vitamins, and active medicinal components like alkaloids. It also mentions pharmaceutical manufacturing of penicillin and basic pharmaceutical products.
#
# Korean: 이 텍스트는 유기 및 무기 화학물질 및 그 파생물, 대량의 식물 약초의 가공, 등급 분쇄 및 분쇄, 아가아가 및 자연 원료의 유사 제품 제조, 내분비 제품, 기본 비타민 제조 또는 분리, 알칼로이드와 같은 활성 약물 원리를 식물 약초로부터 분리하는 것과 관련된 제조 및 가공 활동을 설명합니다. 또한 페니실린의 제약 제조 및 기본 제약품 제조에 대해 언급합니다.
# -----------------------------------
# 35.
# Orginal: hand and edge tools, nec  manufacturing files and other hand and edge tools for metalworking, woodworking, and general maintenance. metal products manufacturing cutting dies, except metal cutting saw blade and handtool manufacturing manufacture of tools manufacture of cutlery, hand tools and general hardware manufacture of toolsother fabricated metal product manufacturing not elsewhere classified
# Summary: The text describes the manufacturing of various hand and edge tools for metalworking, woodworking, and general maintenance, including files and cutting dies. It also mentions the production of cutlery, hand tools, and general hardware under the category of fabricated metal product manufacturing.
#
# Korean: 이 텍스트는 금속 가공, 목공 및 일반 유지보수용으로 사용되는 파일 및 절단 다이 등 다양한 손과 가장 도구의 제조에 대해 설명하고 있습니다. 또한 가공된 금속 제품 제조 범주에서 칼, 손 도구 및 일반 하드웨어의 생산도 언급하고 있습니다.
# -----------------------------------
# 36.
# Orginal: pharmaceutical preparations  manufacturing, fabricating, or processing drugs in pharmaceutical preparations for human or veterinary use. the greater part of the products of these establishments are finished in the form intended for final consumption, such as ampoules, tablets, capsules, vials, ointments, medicinal powders, solutions, and suspensions. products of this industry consist of two important lines, namely: 1 pharmaceutical preparations promoted primarily to the dental, medical, or veterinary professions, and 2 pharmaceutical preparations promoted primarily to the public. pharmaceutical manufacturing pharmaceutical preparations pharmaceutical preparation manufacturing manufacture of pharmaceutical preparations manufacture of pharmaceuticals, medicinal chemical and botanical products manufacture of pharmaceutical preparationshuman pharmaceutical and medicinal product manufacturing
# Summary: The text discusses the manufacturing of pharmaceutical preparations for human or veterinary use, with products including ampoules, tablets, capsules, and ointments. The industry produces pharmaceutical preparations for professionals and the public.
#
# Korean: 이 문서는 인간이나 수의사용 약제 제조에 대해 논하며, 앰플, 정제, 캡슐, 연고 등이 포함된 제품을 생산한다. 이 산업은 전문가와 대중을 위한 약제를 생산한다.
# -----------------------------------
# 37.
# Orginal: data processing and preparation  providing computer processing and data preparation services. the service may consist of complete processing and preparation of reports from data supplied by the customer or a specialized service, such as data entry or making data processing equipment available on an hourly or time-sharing basis. data processing data processing and preparation data processing, hosting, and related services data processing, hosting and related activities data processing, hosting and related activities data processing, hosting and related activitiescomputer system design and related services
# Summary: The text discusses data processing and preparation services, which include processing reports from customer-supplied data, data entry, and providing data processing equipment on an hourly or time-sharing basis. It also mentions computer system design and related services.
#
# Korean: 이 텍스트는 데이터 처리 및 준비 서비스에 대해 다루고 있으며, 이는 고객이 제공한 데이터를 기반으로 보고서를 처리하거나 데이터 입력, 시간당 또는 공유 시간 기반으로 데이터 처리 장비를 제공하는 것을 포함합니다. 또한 컴퓨터 시스템 설계 및 관련 서비스에 대해 언급하고 있습니다.
# -----------------------------------
# 38.
# Orginal: fabricated rubber products, nec, nsk  manufacturing industrial rubber goods, rubberized fabrics, and vulcanized rubber clothing, and miscellaneous rubber specialties and sundries, not elsewhere classified. this also includes reclaiming rubber and rubber articles. rubber and plastic product manufacturing foam rubber all other rubber product manufacturing manufacture of other rubber products manufacture of other rubber products manufacture of other rubber productspolymer product and rubber product manufacturing
# Summary: The text describes the manufacturing of various rubber products such as industrial rubber goods, rubberized fabrics, vulcanized rubber clothing, and miscellaneous rubber specialties. It also includes the reclaiming of rubber and rubber articles.
#
# Korean: 이 텍스트는 산업용 고무제품, 고무 코팅 원단, 황화 고무 의류 및 기타 고무 전문품 등 다양한 고무 제품의 제조를 설명하며, 고무 재생 및 고무 제품도 포함됩니다.
# -----------------------------------
# 39.
# Orginal: custom computer programming services, nsk  providing computer programming services on a contract or fee basis. establishments of this industry perform a variety of additional services, such as computer software design and analysis; modifications of custom software; and training in the use of custom software. computer programming computer software development and applications custom computer programming services computer programming activities computer consultancy and computer facilities management activities computer programming activitiescomputer system design and related services
# Summary: The text describes custom computer programming services that offer services such as computer software design, modifications, and training. It also includes activities related to computer programming, consultancy, facilities management, and system design.
#
# Korean: 이 텍스트는 컴퓨터 프로그래밍 서비스를 제공하는데, 컴퓨터 소프트웨어 디자인, 수정, 교육과 관련된 서비스를 제공합니다. 또한 컴퓨터 프로그래밍, 컨설팅, 시설 관리, 시스템 디자인과 관련된 활동을 포함하고 있습니다.
# -----------------------------------
# 40.
# Orginal: space vehicle equipment, nec, nsk  manufacturing guided missile and space vehicle parts and auxiliary equipment, not elsewhere classified. this industry also includes establishments owned by manufacturers of guided missile and space vehicle parts and auxiliary equipment, not elsewhere classified, and primarily engaged in research and development on such products, whether from enterprise funds or on a contract or fee basis. guided missile and space vehicle manufacturing airframe assemblies, guided missiles other guided missile and space vehicle parts and auxiliary equipment manufacturing manufacture of air and spacecraft and related machinery manufacture of air and spacecraft and related machinery manufacture of air and spacecraft and related machineryaircraft manufacturing and repair services
# Summary: The text describes the manufacturing of guided missile and space vehicle parts and auxiliary equipment, including research and development activities in this industry. It also mentions the manufacture of air and spacecraft machinery, as well as aircraft manufacturing and repair services.
#
# Korean: 이 텍스트는 유도 미사일 및 우주 운송수단 부품 및 보조 장비 제조에 대해 설명하며, 이 산업에서의 연구 및 개발 활동을 언급합니다. 또한 항공 및 우주 운송수단 기계류 제조, 항공기 제조 및 수리 서비스도 언급하고 있습니다.
# -----------------------------------
# 41.
# Orginal: turbines and turbine generator sets, nsk  manufacturing steam turbines; hydraulic turbines; gas turbines, except aircraft; and complete steam, gas, and hydraulic turbine generator set units. also included in this industry are the manufacture of wind and solar powered turbine generators and windmills for generating electric power. machinery and equipment manufacturing turbines and turbine generator sets and parts turbine and turbine generator set units manufacturing manufacture of engines and turbines, except aircraft, vehicle and cycle engines manufacture of engines and turbines, except aircraft, vehicle and cycle engines manufacture of engines and turbines, except aircraft, vehicle and cycle enginesother machinery and equipment manufacturing not elsewhere classified
# Summary: The text discusses the manufacturing of turbines and turbine generator sets, including steam turbines, hydraulic turbines, gas turbines, wind and solar powered turbine generators, and windmills for generating electric power. It also mentions the manufacture of engines and turbines, excluding aircraft, vehicle, and cycle engines.
#
# Korean: 요약: 이 텍스트는 증기 터빈, 수력 터빈, 가스 터빈, 풍력 및 태양열 발전 터빈 발전기, 전기를 생산하는 풍력발전기 및 풍차를 포함한 터빈 및 터빈 발전기 세트의 제조에 대해 다룹니다. 또한 항공기, 차량 및 자전거 엔진을 제외한 엔진 및 터빈의 제조에 대해 언급합니다.
# -----------------------------------
# 42.
# Orginal: blowers and fans  manufacturing industrial and commercial blowers, industrial and commercial exhaust and ventilating fans, and attic fans, or in manufacturing dust collection and other air purification equipment for heating, ventilating and air-conditioning systems or for industrial gas cleaning systems. machinery and equipment manufacturing filters, air: furnaces, air conditioning equipment, etc. industrial and commercial fan and blower and air purification equipment manufacturing manufacture of non-domestic cooling and ventilation equipment manufacture of other general-purpose machinery manufacture of non-domestic cooling and ventilation equipmentother machinery and equipment manufacturing not elsewhere classified
# Summary: The text discusses the manufacturing of blowers, fans, exhaust and ventilating fans, attic fans, dust collection equipment, air purification equipment, filters, furnaces, air conditioning equipment, and other machinery related to heating, ventilating, and air-conditioning systems.
#
# Korean: 텍스트는 블로워, 팬, 배기 및 환기 팬, 다락 팬, 먼지 수집 장비, 공기 정화 장비, 필터, 가스 청정 시스템 및 기타 난방, 환기 및 냉방 시스템 관련 기계장치 제조에 대해 논의합니다.
# -----------------------------------
# 43.
# Orginal: agricultural chemicals, nec  the formulation and preparation of ready-to-use agricultural and household pest control chemicals, including insecticides, fungicides, and herbicides, from technical chemicals or concentrates; and the production of concentrates which require further processing before use as agricultural pesticides. this also includes manufacturing or formulating agricultural chemicals, not elsewhere classified, such as minor or trace elements and soil conditioners. agricultural chemical manufacturing agricultural chemicals, nec pesticide and other agricultural chemical manufacturing manufacture of pesticides and other agrochemical products manufacture of pesticides and other agrochemical products manufacture of pesticides and other agrochemical productspesticide manufacturing
# Summary: The text discusses the manufacturing and formulation of agricultural chemicals, including pest control chemicals like insecticides, fungicides, and herbicides. It also includes the production of concentrates that need further processing before use as pesticides, as well as the manufacturing of minor elements and soil conditioners.
#
# Korean: 이 텍스트는 농업 화학물질의 제조 및 조성에 대해 다루며, 이는 살충제, 살균제 및 제초제와 같은 해충 퇴치 화학물질을 포함합니다. 또한 농약으로 사용되기 전에 추가 처리가 필요한 농약용 농축액의 생산과 더불어 소량 원소 및 토양 개량제의 제조도 포함됩니다.
# -----------------------------------
# 44.
# Orginal: construction materials, nec, nsk  the wholesale distribution of mobile homes and of construction materials, not elsewhere classified, including prefabricated buildings and glass. nonclassifiable establishments construction materials, nec other construction material merchant wholesalers nonclassifiable establishments wholesale of construction materials, hardware, plumbing and heating equipment and supplies wholesale of wood, construction materials and sanitary equipmentnonclassifiable establishments
# Summary: The text describes the wholesale distribution of various construction materials, including mobile homes, prefabricated buildings, glass, hardware, plumbing, heating equipment, wood, and sanitary equipment.
#
# Korean: 텍스트는 모바일 홈, 사전 제작된 건물, 유리, 하드웨어, 배관, 난방 장비, 목재, 위생 장비를 포함한 다양한 건설 자재의 도매 유통을 설명합니다.
# -----------------------------------
# 45.
# Orginal: industrial machinery and equipment  the wholesale distribution of industrial machinery and equipment, not elsewhere classified. nonclassifiable establishments industrial machinery and equipment industrial machinery and equipment merchant wholesalers nonclassifiable establishments wholesale of other machinery and equipment wholesale of other machinery, equipment and suppliesnonclassifiable establishments
# Summary: The text discusses the wholesale distribution of industrial machinery and equipment, including nonclassifiable establishments and the wholesale of other machinery, equipment, and supplies.
#
# Korean: 이 텍스트는 산업용 기계 및 장비의 도매 유통에 대해 다루며, 비분류 업체 및 다른 기계, 장비 및 용품의 도매에 대해 설명합니다.
# -----------------------------------
# 46.
# Orginal: construction and mining machinery  the wholesale distribution of construction or mining cranes, excavating machinery and equipment, power shovels, road construction and maintenance machinery, tractor-mounting equipment and other specialized machinery and equipment used in the construction, mining, and logging industries. machinery wholesale construction and mining machinery, nec construction and mining (except oil well) machinery and equipment merchant wholesalers wholesale of mining, construction and civil engineering machinery wholesale of other machinery and equipment wholesale of mining, construction and civil engineering machineryagricultural and construction machinery wholesaling
# Summary: The text discusses the wholesale distribution of construction and mining machinery, including cranes, excavating equipment, power shovels, and specialized machinery used in various industries.
#
# Korean: 요약: 이 텍스트는 건설 및 광업 기계의 도매 유통에 대해 다루며, 크레인, 굴삭기, 파워 쇼벨 및 다양한 산업에서 사용되는 특수 기계를 포함합니다.
# -----------------------------------
# 47.
# Orginal: agricultural chemicals, nec  the formulation and preparation of ready-to-use agricultural and household pest control chemicals, including insecticides, fungicides, and herbicides, from technical chemicals or concentrates; and the production of concentrates which require further processing before use as agricultural pesticides. this also includes manufacturing or formulating agricultural chemicals, not elsewhere classified, such as minor or trace elements and soil conditioners. agricultural chemical manufacturing pesticides, agricultural or household pesticide and other agricultural chemical manufacturing manufacture of pesticides and other agrochemical products manufacture of pesticides and other agrochemical products manufacture of pesticides and other agrochemical productspesticide manufacturing
# Summary: The text describes the manufacturing of agricultural chemicals, including pest control chemicals like insecticides, fungicides, and herbicides. It also includes the production of concentrates that need further processing before use as pesticides.
#
# Korean: 요약: 이 텍스트는 농업 화학물질 제조에 관한 것으로, 살충제, 농약 및 제초제와 같은 해충 퇴치 화학물질의 제조를 다룹니다. 또한 농약으로 사용되기 전에 추가 처리가 필요한 농약 농축액의 생산도 포함됩니다.
# -----------------------------------
# 48.
# Orginal: paperboard mills, nsk  manufacturing paperboard, including paperboard coated on the paperboard machine, from wood pulp and other fiber pulp; and which may also manufacture converted paperboard products. paper product manufacturing paperboard mills paperboard mills manufacture of paper and paperboard manufacture of pulp, paper and paperboard manufacture of corrugated paper and paperboard and of containers of paper and paperboardpulp, paper and paperboard manufacturing
# Summary: Paperboard mills are facilities that manufacture paperboard from wood pulp and other fiber pulp, which can also produce converted paperboard products. They are involved in the manufacturing of paper, paperboard, corrugated paper, containers, and pulp products.
#
# Korean: 종이판지 공장은 목재 펄프 및 기타 섬유 펄프로부터 종이판지를 생산하며 변환된 종이판지 제품도 생산할 수 있는 시설입니다. 이들은 종이, 종이판지, 골판지, 용기, 그리고 펄프 제품의 제조에 관여합니다.
# -----------------------------------
# 49.
# Orginal: pulp mills, nsk  manufacturing pulp from wood or from other materials, such as rags, linters, wastepaper, and straw. paper product manufacturing pulp mills pulp mills manufacture of pulp manufacture of pulp, paper and paperboard manufacture of pulppulp, paper and paperboard manufacturing
# Summary: Pulp mills are facilities that produce pulp from various materials like wood, rags, wastepaper, and straw for the manufacturing of paper products.
#
# Korean: 펄프 공장은 나무, 걸레, 휴지, 및 짚 등 다양한 재료로부터 펄프를 생산하여 종이 제품을 제조하는 시설입니다.
# -----------------------------------
# 50.
# ...
# Summary: The text discusses broadwoven fabric mills that weave wool fabrics over 12 inches wide primarily using wool, mohair, or similar animal fibers. It also mentions dyeing and finishing processes for wool fabrics, as well as shrinking and sponging wool goods for trade.
#
# Korean: 이 텍스트는 양모, 모헤어 또는 유사한 동물 섬유를 주로 사용하여 12인치 이상 너비의 양모 원단을 짜는 넓은 직물 공장에 대해 다루고 있습니다. 또한 양모 원단의 염색 및 마무리 공정, 그리고 무역을 위해 양모 제품을 수축하고 스폰지 처리하는 과정에 대해 언급하고 있습니다.
# -----------------------------------
# 1701.
# Orginal: blowers and fans  manufacturing industrial and commercial blowers, industrial and commercial exhaust and ventilating fans, and attic fans, or in manufacturing dust collection and other air purification equipment for heating, ventilating and air-conditioning systems or for industrial gas cleaning systems. machinery and equipment manufacturing exhaust fans: industrial or commercial industrial and commercial fan and blower and air purification equipment manufacturing manufacture of non-domestic cooling and ventilation equipment manufacture of other general-purpose machinery manufacture of non-domestic cooling and ventilation equipmentother machinery and equipment manufacturing not elsewhere classified
# Summary: The text discusses the manufacturing of blowers, fans, exhaust fans, and air purification equipment for various industrial and commercial applications, including heating, ventilating, air-conditioning systems, and industrial gas cleaning systems.
#
# Korean: 요약: 이 텍스트는 산업 및 상업용 블로워, 팬, 배기팬 및 공기 정화 장비의 제조에 대해 다루며, 난방, 환기, 냉방 시스템 및 산업용 가스 정화 시스템을 포함한 다양한 산업 및 상업용 용도로 사용됩니다.
# -----------------------------------
# 1702.
# Orginal: nonclassifiable establishments  the wholesale distribution of electronic parts and electronic communications equipment, not elsewhere classified, such as telephone and telegraphic equipment; radio and television broadcasting and communications equipment; and intercommunications equipment. nonclassifiable establishments electronic parts and equipment, nec other electronic parts and equipment merchant wholesalers nonclassifiable establishments wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and partsnonclassifiable establishments
# Summary: The text discusses nonclassifiable establishments involved in the wholesale distribution of various electronic parts and equipment, including telecommunications equipment and intercommunications equipment.
#
# Korean: 요약: 이 텍스트는 전화 및 전신 장비, 라디오 및 텔레비전 방송 및 통신 장비, 그리고 상호 통신 장비와 같은 다양한 전자 부품 및 장비를 도매 유통하는 분류되지 않은 기관에 대해 설명합니다.
# -----------------------------------
# 1703.
# Orginal: cement, hydraulic, nsk  manufacturing hydraulic cement, including portland, natural, masonry, and pozzolana cements. cement and concrete product manufacturing natural cement cement manufacturing manufacture of cement manufacture of cement, lime and plaster manufacture of cementcement and lime manufacturing
# Summary: The text discusses the manufacturing of hydraulic cement, including various types such as portland, natural, masonry, and pozzolana cements.
#
# Korean: 이 텍스트는 포틀랜드, 천연, 벽돌 및 포졸라나 시멘트를 포함한 수소 시멘트의 제조에 대해 논의합니다.
# -----------------------------------
# 1704.
# Orginal: industrial supplies, nsk  the wholesale distribution of industrial supplies, not elsewhere classified. machinery wholesale welding supplies industrial supplies merchant wholesalers wholesale of other machinery and equipment wholesale of other machinery and equipment wholesale of other intermediate productsother specialised industrial machinery and equipment wholesaling
# Summary: The text describes the wholesale distribution of industrial supplies, including machinery, welding supplies, and other specialized industrial machinery and equipment.
#
# Korean: 이 텍스트는 기계, 용접용품 및 기타 특수 산업용 기계 및 장비를 포함한 산업 용품의 도매 유통에 대해 설명합니다.
# -----------------------------------
# 1705.
# Orginal: freight transportation arrangement, nsk  furnishing shipping information and acting as agents in arranging transportation for freight and cargo. also included in this industry are freight forwarders which undertake the transportation of goods from the shippers to receivers for a charge covering the entire transportation, and, in turn, make use of the services of other transportation establishments as instrumentalities in effecting delivery. road transportation services customs clearance of freight freight transportation arrangement other transportation support activities other transportation support activities other transportation support activitiesother transport support services not elsewhere classified
# Summary: The text describes the freight transportation arrangement industry, including services such as furnishing shipping information, acting as agents for arranging transportation, and providing customs clearance for freight. It also mentions freight forwarders who handle the transportation of goods from shippers to receivers and utilize other transportation services for delivery.
#
# Korean: 이 텍스트는 화물 운송 계획 산업을 설명하며, 배송 정보 제공, 운송 조정을 위한 대리인 역할 및 화물 통관을 포함한 서비스에 대해 언급합니다. 또한 화물 운송 업체가 발송인으로부터 수령인까지의 화물 운송을 처리하고 배송을 위해 다른 운송 서비스를 활용하는 화물 운송업자에 대해 언급합니다.
# -----------------------------------
# 1706.
# Orginal: nonclassifiable establishments  selling primarily lumber, or lumber and a general line of building materials, to the general public. while these establishments may sell primarily to construction contractors, they are known as retail in the trade. the lumber which they sell may include rough and dressed lumber, flooring, molding, doors, sashes, frames, and other millwork. the building materials may include roofing, siding, shingles, wallboard, paint, brick, tile, cement, sand, gravel, and other building materials and supplies. hardware is often an important line sold by retail lumber and building materials dealers. home and garden retail lumber and other building materials home centers retail sale of hardware, paints and glass in specialised stores retail sale of hardware, paints and glass in specialized stores retail sale of hardware, paints and glass in specialised storeshardware and building supplies retailing
# Summary: The text describes nonclassifiable establishments that sell lumber and building materials to the general public, including construction contractors. These retail establishments offer a variety of products such as rough and dressed lumber, flooring, roofing, siding, hardware, and other building supplies.
#
# Korean: 요약: 이 텍스트는 건설업자를 포함한 일반 대중에게 목재와 건축자재를 판매하는 분류되지 않은 업체를 설명합니다. 이러한 소매점은 거친 목재, 마감 목재, 바닥재, 지붕재, 철재, 하드웨어 등 다양한 제품을 제공합니다.
# -----------------------------------
# 1707.
# Orginal: adhesives and sealants, nsk  manufacturing industrial and household adhesives, glues, caulking compounds, sealants, and linoleum, tile, and rubber cements from vegetable, animal, or synthetic plastics materials, purchased or produced in the same establishment. nonclassifiable establishments adhesives adhesive manufacturing nonclassifiable establishments manufacture of other chemical products n.e.c. manufacture of gluesnonclassifiable establishments
# Summary: The text describes the manufacturing of adhesives and sealants, including industrial and household products made from various materials. It also mentions the production of glues and other chemical products not elsewhere classified.
#
# Korean: 이 텍스트는 다양한 재료로 만든 산업용 및 가정용 접착제 및 밀봉제를 제조하는 것을 설명하며, 또한 다른 분류되지 않은 화학 제품 및 접착제 생산을 언급합니다.
# -----------------------------------
# 1708.
# Orginal: homefurnishings  the wholesale distribution of home furnishings and housewares, including antiques; china; glassware and earthenware; lamps including electric; curtains and draperies; linens and towels; and carpets, linoleum, and all other types of hard and soft surface floor coverings. home furnishings wholesale stainless steel flatware home furnishing merchant wholesalers wholesale of china and glassware and cleaning materials wholesale of other household goods wholesale of furniture, carpets and lighting equipmentfurniture and floor covering wholesaling
# Summary: The text discusses the wholesale distribution of various home furnishings and housewares, including antiques, china, glassware, lamps, curtains, linens, carpets, and more.
#
# Korean: 본문은 다양한 가정용 가구 및 집기를 도매로 유통하는 것에 대해 다루고 있으며, 그 중에는 고대품, 중국, 유리제품, 램프, 커튼, 리넨, 카펫 등이 포함됩니다.
# -----------------------------------
# 1709.
# Orginal: drugs, proprietaries, and sundries  the wholesale distribution of prescription drugs, proprietary drugs, druggists' sundries, and toiletries. nonclassifiable establishments animal medicines drugs and druggists' sundries merchant wholesalers nonclassifiable establishments wholesale of other household goods wholesale of pharmaceutical goodsnonclassifiable establishments
# Summary: The text discusses the wholesale distribution of prescription drugs, proprietary drugs, druggists' sundries, and toiletries, including animal medicines. It also mentions the wholesale of other household goods and pharmaceutical goods by nonclassifiable establishments.
#
# Korean: 이 텍스트는 처방전 약물, 소유권 약물, 약국 용품 및 화장품을 도매로 유통하는 것에 대해 언급하며, 동물 약물을 포함합니다. 또한 비분류 업체에 의해 다른 가정용품 및 의약품의 도매에 대해 언급합니다.
# -----------------------------------
# 1710.
# Orginal: warm air heating and air conditioning  the wholesale distribution of warm air heating and air-conditioning equipment and supplies. construction and hardware materials wholesale compressors, air conditioning warm air heating and air-conditioning equipment and supplies merchant wholesalers wholesale of other machinery and equipment wholesale of construction materials, hardware, plumbing and heating equipment and supplies wholesale of hardware, plumbing and heating equipment and suppliesother electrical and electronic goods wholesaling
# Summary: The text describes the wholesale distribution of warm air heating and air conditioning equipment and supplies, as well as other related machinery and equipment such as compressors. It also includes the wholesale of construction materials, hardware, plumbing, heating equipment, and other electrical and electronic goods.
#
# Korean: 이 문서는 온난한 공기 난방 및 에어컨 장비 및 용품의 도매 유통뿐만 아니라 압축기, 건설 자재, 하드웨어, 배관, 난방 장비 및 기타 전기 전자 제품의 도매에 대해 설명하고 있습니다.
# -----------------------------------
# 1711.
# Orginal: automobiles and other motor vehicles, nsk  the wholesale distribution of new and used passenger automobiles, trucks, trailers, and other motor vehicles, including motorcycles, motor homes, and snowmobiles. motor vehicle wholesale motorcycles automobile and other motor vehicle merchant wholesalers sale of motor vehicles sale of motor vehicles sale of motor vehiclesmotor vehicle and motor vehicle parts wholesaling
# Summary: The text discusses the wholesale distribution of various motor vehicles, including passenger automobiles, trucks, trailers, motorcycles, motor homes, and snowmobiles.
#
# Korean: 이 텍스트는 승용 자동차, 트럭, 트레일러, 오토바이, 모터홈 및 스노모빌을 포함한 다양한 모터 차량의 도매 유통에 대해 논의하고 있습니다.
# -----------------------------------
# 1712.
# Orginal: industrial machinery and equipment  the wholesale distribution of industrial machinery and equipment, not elsewhere classified. nonclassifiable establishments drilling bits industrial machinery and equipment merchant wholesalers nonclassifiable establishments wholesale of other machinery and equipment wholesale of other machinery, equipment and suppliesnonclassifiable establishments
# Summary: The text discusses the wholesale distribution of industrial machinery and equipment, including drilling bits and other machinery and equipment supplies by nonclassifiable establishments.
#
# Korean: 이 텍스트는 산업용 기계 및 장비, 드릴 비트 및 기타 기계 장비 용품을 비분류 업체들이 도매로 유통하는 내용을 다룹니다.
# -----------------------------------
# 1713.
# Orginal: printing and writing paper, nsk  the wholesale distribution of printing and writing paper, including envelope paper; fine paper; and groundwood paper. paper wholesale fine paper printing and writing paper merchant wholesalers wholesale of other intermediate products wholesale of waste and scrap and other products n.e.c. wholesale of other machinery, equipment and suppliespaper product wholesaling
# Summary: The text describes the wholesale distribution of various types of printing and writing paper, including fine paper, envelope paper, and groundwood paper, as well as other related products such as waste and scrap, machinery, equipment, and supplies.
#
# Korean: 본 텍스트는 인쇄 및 필기 용지를 포함한 다양한 종류의 종이를 도매 유통하는 것을 설명하며, 고급 종이, 봉투 용지, 그라운드우드 종이 등과 같은 다양한 종이 제품뿐만 아니라 폐기물 및 스크랩, 기계, 장비 및 용품과 같은 관련 제품도 다루고 있습니다.
# -----------------------------------
# 1714.
# Orginal: leather and sheep-lined clothing  manufacturing leather and sheep-lined clothing. nonclassifiable establishments garments, leather other cut and sew apparel manufacturing nonclassifiable establishments manufacture of wearing apparel, except fur apparel manufacture of leather clothesnonclassifiable establishments
# Summary: The text discusses the manufacturing of leather and sheep-lined clothing, as well as other nonclassifiable establishments related to garment production.
#
# Korean: 이 텍스트는 가죽 및 양털 안감 의류 제조 및 다른 분류되지 않은 기업들에 대해 다룹니다.
# -----------------------------------
# 1715.
# Orginal: electronic parts and equipment, nec, nsk  the wholesale distribution of electronic parts and electronic communications equipment, not elsewhere classified, such as telephone and telegraphic equipment; radio and television broadcasting and communications equipment; and intercommunications equipment. electronics wholesale electronic parts other electronic parts and equipment merchant wholesalers wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and partsother electrical and electronic goods wholesaling
# Summary: The text describes the wholesale distribution of various electronic parts and equipment, including telecommunications equipment, radio and television broadcasting equipment, and intercommunications equipment.
#
# Korean: 이 텍스트는 전자 부품 및 장비의 도매 유통을 설명하며, 전화 및 전신 장비, 라디오 및 텔레비전 방송 및 통신 장비, 상호 통신 장비 등이 포함됩니다.
# -----------------------------------
# 1716.
# Orginal: bottled and canned soft drinks, nsk  manufacturing soft drinks and carbonated waters. beverage manufacturing carbonated beverages, nonalcoholic: pkged. in cans, bottles soft drink manufacturing manufacture of soft drinks; production of mineral waters and other bottled waters manufacture of soft drinks; production of mineral waters and other bottled waters manufacture of soft drinks; production of mineral waters and other bottled waterssoft drink, cordial and syrup manufacturing
# Summary: The text discusses the manufacturing of soft drinks, carbonated beverages, and bottled waters in cans and bottles.
#
# Korean: 이 텍스트는 캔과 병에 담긴 소프트 드링크, 탄산음료 및 병입 물을 제조하는 것에 대해 다룹니다.
# -----------------------------------
# 1717.
# Orginal: blast furnaces and steel mills, nsk  manufacturing hot metal, pig iron, and silvery pig iron from iron ore and iron and steel scrap; converting pig iron, scrap iron, and scrap steel into steel; and in hot-rolling iron and steel into basic shapes, such as plates, sheets, strips, rods, bars, and tubing. merchant blast furnaces and by-product or beehive coke ovens are also included in this industry. metal products manufacturing tinplate iron and steel mills and ferroalloy manufacturing manufacture of basic iron and steel and of ferro-alloys manufacture of basic iron and steel manufacture of basic iron and steel and of ferro-alloysiron smelting and steel manufacturing
# Summary: The text describes the processes involved in manufacturing hot metal, pig iron, and steel from iron ore and scrap, as well as the production of basic iron and steel products like plates, sheets, and bars. It also includes the operation of blast furnaces, steel mills, and coke ovens in this industry.
#
# Korean: 요약: 이 텍스트는 철광석과 폐철로부터 열철, 청철, 그리고 강철을 생산하는 과정과 같이, 판, 시트, 막대, 바 및 튜브와 같은 기본 철강 제품을 생산하는 과정을 설명합니다. 또한 이 산업에서 화로, 제철소 및 코크 오븐의 운영도 포함됩니다.

# %%
text_dup_sum_enko = text_dup.copy()

data = []
with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
        data.append(json.loads(line.strip()))
df = pd.DataFrame(data)

cond = df['DSC'].apply(lambda x: x.split('\n\nKorean: '))
for idx in range(len(cond)):
    text_dup_sum_enko.loc[idx, 'DSC_summary'] = cond[idx][0].strip('Summary: ')
    text_dup_sum_enko.loc[idx, 'DSC_enko'] = cond[idx][1]
text_dup_sum_enko.head()
# Out:
#   ID  CODE                                                DSC  \
# 0  1  4520  automotive repair shops, nec  specialized auto...
# 1  2  0149  general farms, primarily animals, nsk  derives...
# 2  3  4630  fish and seafoods  the wholesale distribution ...
# 3  4  4510  new and used car dealers, nsk  manufactures a ...
# 4  4  2930  automotive stampings, nsk  manufacturing autom...
#
#                                          DSC_summary  \
# 0  The text describes various specialized automot...
# 1  The text describes general farms that primaril...
# 2  The text discusses the wholesale distribution ...
# 3  The company manufactures vehicles under Fiat a...
# 4  The text discusses the manufacturing of automo...
#
#                                             DSC_enko
# 0  이 텍스트는 연료 서비스, 기화기 수리, 브레이크 재설치, 휠 정렬 및 라디에이터 ...
# 1  이 텍스트는 주로 가축 생산에 중점을 둔 일반 농장을 설명하며, 이러한 농장들이 가...
# 2  이 텍스트는 살아 있는, 처리된 또는 냉동된 생선과 해산물의 도매 유통에 대해 다루...
# 3  회사는 미국과 멕시코의 다수 공장에서 피아트와 크라이슬러 브랜드를 통해 자동차를 생...
# 4  요약: 이 텍스트는 차량 부품인 바디 부품, 허브 및 트림을 비롯한 자동차 스탬핑의...

# %%
text_sum_enko = text_prepro.copy()

for i in tqdm(range(text_sum_enko.shape[0])):
    for j in range(text_dup_sum_enko.shape[0]):
        if text_sum_enko.loc[i, 'DSC'] == text_dup_sum_enko.loc[j, 'DSC']:
            text_sum_enko.loc[i, 'DSC_summary'] = text_dup_sum_enko.loc[j, 'DSC_summary']
            text_sum_enko.loc[i, 'DSC_enko'] = text_dup_sum_enko.loc[j, 'DSC_enko']
text_sum_enko.head()
# Out:
# 100%|██████████| 10000/10000 [02:55<00:00, 56.83it/s]
#   ID  CODE                                                DSC  \
# 0  1  4520  automotive repair shops, nec  specialized auto...
# 1  2  0149  general farms, primarily animals, nsk  derives...
# 2  3  4630  fish and seafoods  the wholesale distribution ...
# 3  4  4510  new and used car dealers, nsk  manufactures a ...
# 4  4  2930  automotive stampings, nsk  manufacturing autom...
#
#                                          DSC_summary  \
# 0  The text describes various specialized automot...
# 1  The text describes general farms that primaril...
# 2  The text discusses the wholesale distribution ...
# 3  The company manufactures vehicles under Fiat a...
# 4  The text discusses the manufacturing of automo...
#
#                                             DSC_enko
# 0  이 텍스트는 연료 서비스, 기화기 수리, 브레이크 재설치, 휠 정렬 및 라디에이터 ...
# 1  이 텍스트는 주로 가축 생산에 중점을 둔 일반 농장을 설명하며, 이러한 농장들이 가...
# 2  이 텍스트는 살아 있는, 처리된 또는 냉동된 생선과 해산물의 도매 유통에 대해 다루...
# 3  회사는 미국과 멕시코의 다수 공장에서 피아트와 크라이슬러 브랜드를 통해 자동차를 생...
# 4  요약: 이 텍스트는 차량 부품인 바디 부품, 허브 및 트림을 비롯한 자동차 스탬핑의...

# %% [markdown]
# # Document 구성

# %% [markdown]
# ## text

# %%
seq_num = 1
text_documents = []
for idx in range(text_sum_enko.shape[0]):
    doc = Document(
        page_content=f"{text_sum_enko.loc[idx, 'DSC_summary']}\n{text_sum_enko.loc[idx, 'DSC_enko']}", 
        metadata={
            'ID': text_sum_enko.loc[idx, 'ID'],
            'CODE': text_sum_enko.loc[idx, 'CODE'],
            'source': '/root/contest-matching-model/data/jsonl_summary_text.jsonl',
            'seq_num': seq_num,
        }
    )
    text_documents.append(doc)
    seq_num += 1

pprint(text_documents[0])
print(text_documents[0].page_content)
pprint(text_documents[0].metadata)
# Out:
# Document(page_content='The text describes various specialized automotive repair services such as fuel service, carburetor repair, brake relining, wheel alignment, and radiator repair, as well as general motor vehicle repair and maintenance.\n이 텍스트는 연료 서비스, 기화기 수리, 브레이크 재설치, 휠 정렬 및 라디에이터 수리와 같은 다양한 특수 자동차 수리 서비스와 일반 자동차 수리 및 유지보수에 대해 설명하고 있습니다.', metadata={'ID': '1', 'CODE': '4520', 'source': '/root/contest-matching-model/data/jsonl_summary_text.jsonl', 'seq_num': 1})
# The text describes various specialized automotive repair services such as fuel service, carburetor repair, brake relining, wheel alignment, and radiator repair, as well as general motor vehicle repair and maintenance.
# 이 텍스트는 연료 서비스, 기화기 수리, 브레이크 재설치, 휠 정렬 및 라디에이터 수리와 같은 다양한 특수 자동차 수리 서비스와 일반 자동차 수리 및 유지보수에 대해 설명하고 있습니다.
# {'CODE': '4520',
#  'ID': '1',
#  'seq_num': 1,
#  'source': '/root/contest-matching-model/data/jsonl_summary_text.jsonl'}

# %% [markdown]
# ## statis

# %%
file_path = '../data/jsonl_prepro_statis.jsonl'
temp = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        temp.append(json.loads(line.strip()))

seq_num = 1
statis_documents = []
for data in temp:
    doc = Document(
        page_content=f"{data['ISIC4_NAME']}\r\n{data['KSIC10_NAME']}\r\n{data['HS2017_NAME']}", # ISIC4, KSIC10, HS2017 순으로 작성됨
        metadata={
            'ISIC4_CODE': data['ISIC4_CODE'],
            'KSIC10_CODE': data['KSIC10_CODE'],
            'HS2017_CODE': data['HS2017_CODE'],
            'source': '/root/contest-matching-model/data/jsonl_prepro_statis.jsonl',
            'seq_num': seq_num,
        }
    )
    statis_documents.append(doc)
    seq_num += 1

pprint(statis_documents[0])
print(statis_documents[0].page_content)
pprint(statis_documents[0].metadata)
# Out:
# Document(page_content='곡물(쌀 제외), 콩류, 종실유 재배업\r\n종자 및 묘목 생산업\r\n종자', metadata={'ISIC4_CODE': '0111', 'KSIC10_CODE': '01123', 'HS2017_CODE': '100111', 'source': '/root/contest-matching-model/data/jsonl_prepro_statis.jsonl', 'seq_num': 1})
# 곡물(쌀 제외), 콩류, 종실유 재배업
# 종자 및 묘목 생산업
# 종자
# {'HS2017_CODE': '100111',
#  'ISIC4_CODE': '0111',
#  'KSIC10_CODE': '01123',
#  'seq_num': 1,
#  'source': '/root/contest-matching-model/data/jsonl_prepro_statis.jsonl'}

# %% [markdown]
# ## customs

# %%
file_path = '../data/jsonl_prepro_customs.jsonl'
temp = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        temp.append(json.loads(line.strip()))

seq_num = 1
customs_documents = []
for data in temp:
    doc = Document(
        page_content=f"{data['KOR_NAME']}\r\n{data['ENG_NAME']}\r\n{data['INT_NAME']}", # 한글품목명, 영어품목명, 성질 통합 분류명 순으로 작성됨
        metadata={
            'HS_CODE': data['HS_CODE'],
            'INT_CODE': data['INT_CODE'],
            'source': '/root/contest-matching-model/data/jsonl_prepro_customs.jsonl',
            'seq_num': seq_num,
        }
    )
    customs_documents.append(doc)
    seq_num += 1

pprint(customs_documents[0])
print(customs_documents[0].page_content)
pprint(customs_documents[0].metadata)
# Out:
# Document(page_content='농가 사육용\r\nFor farm breeding\r\n말', metadata={'HS_CODE': '0101211000', 'INT_CODE': '11020101', 'source': '/root/contest-matching-model/data/jsonl_prepro_customs.jsonl', 'seq_num': 1})
# 농가 사육용
# For farm breeding
# 말
# {'HS_CODE': '0101211000',
#  'INT_CODE': '11020101',
#  'seq_num': 1,
#  'source': '/root/contest-matching-model/data/jsonl_prepro_customs.jsonl'}

# %% [markdown]
# # Text Splitter

# %% [markdown]
# ## statis

# %%
# content 길이 확인
length = []
content = []
for idx in range(0, len(statis_documents)):
    cond = statis_documents[idx].page_content
    a = len(cond)
    b = cond
    length.append(a)
    content.append(b)

df = pd.DataFrame({
    'length': length,
    'content': content
})

# %%
df.head()
# Out:
#    length                                          content
# 0      38       곡물(쌀 제외), 콩류, 종실유 재배업\r\n종자 및 묘목 생산업\r\n종자
# 1       8                                      \r\n \r\n종자
# 2      43  곡물(쌀 제외), 콩류, 종실유 재배업\r\n곡물 및 기타 식량작물 재배업\r\n기타
# 3       8                                      \r\n \r\n기타
# 4      39      곡물(쌀 제외), 콩류, 종실유 재배업\r\n종자 및 묘목 생산업\r\n종자용

# %%
df.describe()
# Out:
#             length
# count  8519.000000
# mean     31.357554
# std      28.675302
# min       7.000000
# 25%      13.000000
# 50%      24.000000
# 75%      40.000000
# max     299.000000

# %%
df[df['length'] == 7].reset_index().loc[0, 'content']
# Out:
# ' \r\n \r\n '

# %%
# # Split
# splitter = RecursiveCharacterTextSplitter(
#     separators=['\r\n', '. ', ', ', ' ', ''],
#     chunk_size=100,
#     chunk_overlap=0,
#     length_function=len,
# )
# statis_splits = splitter.split_documents(statis_documents)

# print(f'> Text Splitter 적용 전 문서 개수: {len(statis_documents)}\n> Text Splitter 적용 후 문서 개수: {len(statis_splits)}')
# print(f'\n\nText Splitter 적용 전 page_content:\n{statis_documents[0].page_content}\n\nText Splitter 적용 후 page_content:\n{statis_splits[0].page_content}')

# %% [markdown]
# ## customs

# %%
# content 길이 확인
length = []
content = []
for idx in range(0, len(customs_documents)):
    cond = customs_documents[idx].page_content
    a = len(cond)
    b = cond
    length.append(a)
    content.append(b)

df = pd.DataFrame({
    'length': length,
    'content': content
})

# %%
df.head()
# Out:
#    length                           content
# 0      28  농가 사육용\r\nFor farm breeding\r\n말
# 1      12                  기타\r\nOther\r\n말
# 2      25     경주말\r\nHorses for racing\r\n말
# 3      12                  기타\r\nOther\r\n말
# 4      19           당나귀\r\nAsses\r\n기타 산 동물

# %%
df.describe()
# Out:
#              length
# count  12422.000000
# mean      47.491547
# std       49.001142
# min       10.000000
# 25%       19.000000
# 50%       32.000000
# 75%       56.000000
# max      869.000000

# %%
df[df['length'] >= 800].reset_index().loc[0, 'content']
# Out:
# '틸라피아[오레오크로미스(Oreochromis)속], 메기[판가시우스(Pangasius)속ㆍ실루러스(Silurus)속ㆍ클라리아스(Clarias)속ㆍ익타루러스(Ictalurus)속], 잉어[사이프리너스(Cyprinus)속ㆍ카라시우스(Carassius)속ㆍ크테노파린고돈 이델루스(Ctenopharyngodon idellus)ㆍ하이포프탈미크티스(Hypophthalmichthys)속ㆍ시리누스(Cirrhinus)속ㆍ마일로파린고돈 피세우스(Mylopharyngodon piceus)ㆍ카틀라 카틀라(Catla catla)ㆍ라베오(Labeo)속ㆍ오스테오킬루스 하셀티(Osteochilus hasselti)ㆍ렙토바르부스 호에베니(Leptobarbus hoeveni)ㆍ메갈로브라마(Megalobrama)속], 뱀장어[앙귈라(Anguilla)속], 나일 퍼치[라테스 니로티쿠스(Lates niloticus)], 가물치[카나(Channa)속]\r\nTilapias (Oreochromis spp.), catfish (Pangasius spp., Silurus spp., Clarias spp., Ictalurus spp.), carp (Cyprinus spp., Carassius spp., Ctenopharyngodon idellus, Hypophthalmichthys spp., Cirrhinus spp., Mylopharyngodon piceus, Catla catla, Labeo spp., Osteochilus hasselti, Leptobarbus hoeveni, Megalobrama spp.), eels (Anguilla spp.), Nile perch (Lates niloticus) and snakeheads (Channa spp.)\r\n기타 어류(훈제)'

# %%
# # Split
# splitter = RecursiveCharacterTextSplitter(
#     separators=['\r\n', '. ', ', ', ' ', ''],
#     chunk_size=70,
#     chunk_overlap=0,
#     length_function=len,
# )
# customs_splits = splitter.split_documents(customs_documents)

# print(f'> Text Splitter 적용 전 문서 개수: {len(customs_documents)}\n> Text Splitter 적용 후 문서 개수: {len(customs_splits)}')
# print(f'\n\nText Splitter 적용 전 page_content:\n{customs_documents[0].page_content}\n\nText Splitter 적용 후 page_content:\n{customs_splits[0].page_content}')

# %% [markdown]
# # 벡터스토어 생성
#
# > 통계청, 관세청만 해당함 (텍스트는 인풋 값이어서 벡터스토어에 안 넣음)

# %%
# Embedding
embeddings = OpenAIEmbeddings(
    api_key=OPENAI_API_KEY,
    model='text-embedding-3-large'
)

# %% [markdown]
# ## statis

# %%
name = 'statis'
folder_path = f'./vectorstore/EXP05/{name}'
if not os.path.exists(folder_path):
    print(f'> "{folder_path}" 생성 중')
    statis_vectorstore = FAISS.from_documents(
        documents=statis_documents,
        embedding=embeddings,
    )
    statis_vectorstore.save_local(folder_path=folder_path)
    print(f'> "{folder_path}" 생성 및 로컬 저장 완료')
else:
    statis_vectorstore = FAISS.load_local(
        folder_path=folder_path, 
        embeddings=embeddings, 
        allow_dangerous_deserialization=True
    )
    print(f'> "{folder_path}" 로컬에서 불러옴')
# Out:
# > "./vectorstore/EXP05/statis" 생성 중
# > "./vectorstore/EXP05/statis" 생성 및 로컬 저장 완료

# %%
statis_retriever = statis_vectorstore.as_retriever(search_kwargs={'k': 3})

# %% [markdown]
# ## customs

# %%
name = 'customs'
folder_path = f'./vectorstore/EXP05/{name}'
if not os.path.exists(folder_path):
    print(f'> "{folder_path}" 생성 중')
    customs_vectorstore = FAISS.from_documents(
        documents=customs_documents,
        embedding=embeddings,
    )
    customs_vectorstore.save_local(folder_path=folder_path)
    print(f'> "{folder_path}" 생성 및 로컬 저장 완료')
else:
    customs_vectorstore = FAISS.load_local(
        folder_path=folder_path, 
        embeddings=embeddings, 
        allow_dangerous_deserialization=True
    )
    print(f'> "{folder_path}" 로컬에서 불러옴')
# Out:
# > "./vectorstore/EXP05/customs" 로컬에서 불러옴

# %%
customs_retriever = customs_vectorstore.as_retriever(search_kwargs={'k': 3})

# %% [markdown]
# # 적절한 HS CODE 찾는 프로세스
#
# > 텍스트의 jsonl 한 줄 들어옴
#
# > 텍스트의 ISIC4와 통계청의 ISIC4 같은거 찾기 (metadata 끼리 비교)<br>근데 ISIC4_CODE 결측치 존재함.<br>텍스트가 답인 것 같음! 유사도 검색 수행도 해서 비교하기
#
# > 조건 거친 통계청의 page_content와(topk(아마 k=5 예상)) 텍스트의 page_content를 컨텍스트로 주고, 관세청의 page_content와 비교
#
# > 관세청 HS_CODE topk(k >= 10) 추출
#
# > 위 과정에서 레퍼런스 잘 챙기기

# %% [markdown]
# ## statis query = text

# %%
query = text_documents[0].page_content

statis_results = statis_retriever.invoke(query)

i = 1
statis_query = ''
print('[statis]')
for res in statis_results:
    print('-----' * 7)
    print(f'{i}.')
    print(res.page_content)
    statis_query += f'\n{res.page_content}'
    i += 1
print('-----' * 7)
print(statis_query)
# Out:
# [statis]
# -----------------------------------
# 1.
# 자동차 정비 및 수리업
# 자동차 전문 수리업
#
# -----------------------------------
# 2.
# 자동차 정비 및 수리업
# 자동차 종합 수리업
#
# -----------------------------------
# 3.
# 자동차 정비 및 수리업
# 자동차 종합 수리업
#
# -----------------------------------
#
# 자동차 정비 및 수리업
# 자동차 전문 수리업
#
# 자동차 정비 및 수리업
# 자동차 종합 수리업
#
# 자동차 정비 및 수리업
# 자동차 종합 수리업

# %% [markdown]
# ## customs query = text

# %%
customs_results = customs_retriever.invoke(query)

i = 1
print('[customs]')
for res in customs_results:
    print('-----' * 7)
    print(f'{i}.')
    print(res.page_content)
    i += 1
# Out:
# [customs]
# -----------------------------------
# 1.
# 자동차용
# For automobiles
# 자동차 부품
# -----------------------------------
# 2.
# 승용자동차용[스테이션왜건(station wagon)과 경주 자동차용을 포함한다]
# Of a kind used on motor cars (including station wagons and racing cars)
# 고무타이어 및 타이어튜브
# -----------------------------------
# 3.
# 승용자동차용[스테이션왜건(station wagon)과 경주 자동차용을 포함한다]
# Of a kind used on motor cars (including station wagons and racing cars)
# 고무타이어 및 타이어튜브

# %% [markdown]
# ## customs query = statis topk

# %%
customs_results = customs_retriever.invoke(statis_query)

i = 1
print('[customs]')
for res in customs_results:
    print('-----' * 7)
    print(f'{i}.')
    print(res.page_content)
    i += 1
# Out:
# [customs]
# -----------------------------------
# 1.
# 자동차용
# For automobiles
# 자동차 부품
# -----------------------------------
# 2.
# 부분품
# Parts
# 자동차 부품
# -----------------------------------
# 3.
# 부분품
# Parts
# 자동차 부품

# %% [markdown]
# ## 전체

# %%
# vectorstore as retriever
statis_retriever = statis_vectorstore.as_retriever(search_type='similarity', search_kwargs={'k': 3})
customs_retriever = customs_vectorstore.as_retriever(search_type='similarity', search_kwargs={'k': 3})

# Create directory
statis_file_path = '../submit/EXP05/statis.jsonl'
os.makedirs(os.path.dirname(statis_file_path), exist_ok=True)
customs_file_path = '../submit/EXP05/customs.jsonl'
os.makedirs(os.path.dirname(customs_file_path), exist_ok=True)

# IR
for text_document in tqdm(text_documents):
    # query
    query = text_document.page_content

    # statis retriever
    statis_results = statis_retriever.invoke(query)

    # Save References and Create new query
    idx = 0
    statis_query = ''
    with open(statis_file_path, 'a', encoding='utf-8') as ref:
        statis_references = {
            "ISIC4_CODE": "", 
            "KSIC10_CODE": "", 
            "HS2017_CODE": "", 
            "result": ""
        }        
        isic4 = [reference.metadata['ISIC4_CODE'] for reference in statis_results]
        ksic10 = [reference.metadata['KSIC10_CODE'] for reference in statis_results]
        hs2017 = [reference.metadata['HS2017_CODE'] for reference in statis_results]
        result = [reference.page_content for reference in statis_results]
        statis_references['ISIC4_CODE'] = isic4
        statis_references['KSIC10_CODE'] = ksic10
        statis_references['HS2017_CODE'] = hs2017
        statis_references['result'] = result

        ref.write(f'{json.dumps(statis_references, ensure_ascii=False)}\n')

        for res in statis_results:
            statis_query += f'\n{res.page_content}'
        
        # customs retriever
        customs_results = customs_retriever.invoke(statis_query)

        # Save References
        with open(customs_file_path, 'a', encoding='utf-8') as ref:
            customs_references = {
                "HS_CODE": "", 
                "INT_CODE": "", 
                "result": ""
            }        
            hscode = [reference.metadata['HS_CODE'] for reference in customs_results]
            intcode = [reference.metadata['INT_CODE'] for reference in customs_results]
            result = [reference.page_content for reference in customs_results]
            customs_references['HS_CODE'] = hscode
            customs_references['INT_CODE'] = intcode
            customs_references['result'] = result

            ref.write(f'{json.dumps(customs_references, ensure_ascii=False)}\n')
# Out:
# 100%|██████████| 10000/10000 [2:45:10<00:00,  1.01it/s]
