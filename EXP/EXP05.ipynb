# %%
from dotenv import load_dotenv
load_dotenv()

import os
import re
import csv
import json
import time
import numpy as np
import pandas as pd
from pprint import pprint
from tqdm import tqdm

from langchain import hub
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_community.vectorstores import FAISS
from langchain_upstage import ChatUpstage
from langchain.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, PromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
OPENAI_API_KEY = os.environ.get('OPENAI_API_KEY')
UPSTAGE_API_KEY = os.environ.get('UPSTAGE_API_KEY')
LANGCHAIN_API_KEY = os.environ.get('LANGCHAIN_API_KEY')
# os.environ['LANGCHAIN_PROJECT'] = 'matching_model_EXP06' # 프로젝트명 수정
# os.environ['LANGCHAIN_TRACING_V2'] = 'true'
LANGCHAIN_PROJECT = os.environ.get('LANGCHAIN_PROJECT')

print(f'> LangSmith Project: {LANGCHAIN_PROJECT}')
# Out:
# > LangSmith Project: matching_model_EXP06

# %% [markdown]
# # 데이터 구성
#
# > 전처리, csv to jsonl

# %%
# 데이터 로드

text = pd.read_excel('../data/비식별된 해외기업별 영문 텍스트데이터.xlsx')
statis = pd.read_excel('../data/통계청 국제표준산업분류 HSCODE 6단위 매핑.xlsx')
customs = pd.read_excel('../data/관세청_HS부호_240101.xlsx')

text_copy = text.copy()
statis_copy = statis.copy()
customs_copy = customs.copy()

print('> 데이터 로드 완료')


# 데이터 전처리

def zero_input(num, x):
    if pd.isna(x):
        return np.nan
    else:
        cnt = num - len(x)
        return '0' * cnt + x
    
def re_sub(x):
    if pd.isna(x):
        return np.nan
    else:
        return re.sub(r'^\((.*?)\)$', r'\1', x)

text_copy['ID'] = text_copy['ID'].astype(str)
text_copy['CODE'] = text_copy['CODE'].astype(str)
text_copy['CODE'] = text_copy['CODE'].apply(lambda x: zero_input(4, x))

statis_copy.columns = [
    'ISIC4_CODE', # ISIC4_국제표준산업분류
    'ISIC4_NAME', # ISIC4_분류명
    'KSIC10_CODE', # KSIC10_한국표준산업분류
    'KSIC10_NAME', # KSIC10_분류명
    'HS2017_CODE', # HS2017_관세통계통합품목분류
    'HS2017_NAME' # HS2017_분류명
]

statis_copy['ISIC4_CODE'] = statis_copy['ISIC4_CODE'].astype(str)
statis_copy['ISIC4_CODE'] = statis_copy['ISIC4_CODE'].replace('nan', np.nan)
statis_copy['ISIC4_CODE'] = statis_copy['ISIC4_CODE'].str.replace('.0', '', regex=False)
statis_copy['ISIC4_CODE'] = statis_copy['ISIC4_CODE'].apply(lambda x: zero_input(4, x))

statis_copy['HS2017_CODE'] = statis_copy['HS2017_CODE'].astype(str)
statis_copy['HS2017_CODE'] = statis_copy['HS2017_CODE'].replace('nan', np.nan)
statis_copy['HS2017_CODE'] = statis_copy['HS2017_CODE'].str.replace('.0', '', regex=False)
statis_copy['HS2017_CODE'] = statis_copy['HS2017_CODE'].apply(lambda x: zero_input(6, x))

customs_copy.columns = [
    'HS_CODE', # HS부호
    'KOR_NAME', # 한글품목명
    'ENG_NAME', # 영문품목명
    'INT_CODE', # 성질통합분류코드
    'INT_NAME' # 성질통합분류명
]

customs_copy['HS_CODE'] = customs_copy['HS_CODE'].astype(str)
customs_copy['HS_CODE'] = customs_copy['HS_CODE'].apply(lambda x: zero_input(10, x))

customs_copy['INT_CODE'] = customs_copy['INT_CODE'].astype(str)
customs_copy['INT_CODE'] = customs_copy['INT_CODE'].replace('nan', np.nan)
customs_copy['INT_CODE'] = customs_copy['INT_CODE'].str.replace('.0', '', regex=False)

customs_copy['INT_NAME'] = customs_copy['INT_NAME'].apply(lambda x: re_sub(x))

text_copy = text_copy.fillna(' ')
statis_copy = statis_copy.fillna(' ')
customs_copy = customs_copy.fillna(' ')

print('> 데이터 전처리 완료')
print('> 데이터 결측치 확인')
print('-----' * 5)
print(text_copy.isnull().sum())
print(statis_copy.isnull().sum())
print(customs_copy.isnull().sum())
print('-----' * 5)


# 데이터 저장 및 로드

text_copy.to_csv('../data/prepro_text.csv', index=False, encoding='utf-8')
statis_copy.to_csv('../data/prepro_statis.csv', index=False, encoding='utf-8')
customs_copy.to_csv('../data/prepro_customs.csv', index=False, encoding='utf-8')

text_prepro = pd.read_csv('../data/prepro_text.csv', dtype=str)
statis_prepro = pd.read_csv('../data/prepro_statis.csv', dtype=str)
customs_prepro = pd.read_csv('../data/prepro_customs.csv', dtype=str)


# csv to jsonl

def csv_to_jsonl(csv_file_path, jsonl_file_path):
    with open(csv_file_path, mode='r', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        with open(jsonl_file_path, mode='w', encoding='utf-8') as jsonl_file:
            for row in csv_reader:
                jsonl_file.write(json.dumps(row, ensure_ascii=False) + '\n')

csv_to_jsonl('../data/prepro_text.csv', '../data/jsonl_prepro_text.jsonl')
csv_to_jsonl('../data/prepro_statis.csv', '../data/jsonl_prepro_statis.jsonl')
csv_to_jsonl('../data/prepro_customs.csv', '../data/jsonl_prepro_customs.jsonl')
print('> csv to jsonl 완료')
# Out:
# > 데이터 로드 완료
# > 데이터 전처리 완료
# > 데이터 결측치 확인
# -------------------------
# ID      0
# CODE    0
# DSC     0
# dtype: int64
# ISIC4_CODE     0
# ISIC4_NAME     0
# KSIC10_CODE    0
# KSIC10_NAME    0
# HS2017_CODE    0
# HS2017_NAME    0
# dtype: int64
# HS_CODE     0
# KOR_NAME    0
# ENG_NAME    0
# INT_CODE    0
# INT_NAME    0
# dtype: int64
# -------------------------
# > csv to jsonl 완료

# %% [markdown]
# # Document 구성

# %% [markdown]
# ## text

# %%
file_path = '../data/jsonl_prepro_text.jsonl'
temp = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        temp.append(json.loads(line.strip()))

seq_num = 1
text_documents = []
for data in temp:
    doc = Document(
        page_content=data['DSC'], 
        metadata={
            'ID': data['ID'],
            'CODE': data['CODE'],
            'source': '/root/contest-matching-model/data/jsonl_prepro_text.jsonl',
            'seq_num': seq_num,
        }
    )
    text_documents.append(doc)
    seq_num += 1

pprint(text_documents[0])
print(text_documents[0].page_content)
pprint(text_documents[0].metadata)
# Out:
# Document(page_content='automotive repair shops, nec  specialized automotive repair, not elsewhere classified, such as fuel service carburetor repair, brake relining, front-end and wheel alignment, and radiator repair. motor vehicle repair and maintenance auto brake lining, installation other automotive mechanical and electrical repair and maintenance maintenance and repair of motor vehicles maintenance and repair of motor vehicles maintenance and repair of motor vehiclesother automotive repair and maintenance', metadata={'ID': '1', 'CODE': '4520', 'source': '/root/contest-matching-model/data/jsonl_prepro_text.jsonl', 'seq_num': 1})
# automotive repair shops, nec  specialized automotive repair, not elsewhere classified, such as fuel service carburetor repair, brake relining, front-end and wheel alignment, and radiator repair. motor vehicle repair and maintenance auto brake lining, installation other automotive mechanical and electrical repair and maintenance maintenance and repair of motor vehicles maintenance and repair of motor vehicles maintenance and repair of motor vehiclesother automotive repair and maintenance
# {'CODE': '4520',
#  'ID': '1',
#  'seq_num': 1,
#  'source': '/root/contest-matching-model/data/jsonl_prepro_text.jsonl'}

# %% [markdown]
# ## statis

# %%
file_path = '../data/jsonl_prepro_statis.jsonl'
temp = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        temp.append(json.loads(line.strip()))

seq_num = 1
statis_documents = []
for data in temp:
    doc = Document(
        page_content=f"{data['ISIC4_NAME']}\r\n{data['KSIC10_NAME']}\r\n{data['HS2017_NAME']}", # ISIC4, KSIC10, HS2017 순으로 작성됨
        metadata={
            'ISIC4_CODE': data['ISIC4_CODE'],
            'KSIC10_CODE': data['KSIC10_CODE'],
            'HS2017_CODE': data['HS2017_CODE'],
            'source': '/root/contest-matching-model/data/jsonl_prepro_statis.jsonl',
            'seq_num': seq_num,
        }
    )
    statis_documents.append(doc)
    seq_num += 1

pprint(statis_documents[0])
print(statis_documents[0].page_content)
pprint(statis_documents[0].metadata)
# Out:
# Document(page_content='곡물(쌀 제외), 콩류, 종실유 재배업\r\n종자 및 묘목 생산업\r\n종자', metadata={'ISIC4_CODE': '0111', 'KSIC10_CODE': '01123', 'HS2017_CODE': '100111', 'source': '/root/contest-matching-model/data/jsonl_prepro_statis.jsonl', 'seq_num': 1})
# 곡물(쌀 제외), 콩류, 종실유 재배업
# 종자 및 묘목 생산업
# 종자
# {'HS2017_CODE': '100111',
#  'ISIC4_CODE': '0111',
#  'KSIC10_CODE': '01123',
#  'seq_num': 1,
#  'source': '/root/contest-matching-model/data/jsonl_prepro_statis.jsonl'}

# %% [markdown]
# ## customs

# %%
file_path = '../data/jsonl_prepro_customs.jsonl'
temp = []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        temp.append(json.loads(line.strip()))

seq_num = 1
customs_documents = []
for data in temp:
    doc = Document(
        page_content=f"{data['KOR_NAME']}\r\n{data['ENG_NAME']}\r\n{data['INT_NAME']}", # 한글품목명, 영어품목명, 성질 통합 분류명 순으로 작성됨
        metadata={
            'HS_CODE': data['HS_CODE'],
            'INT_CODE': data['INT_CODE'],
            'source': '/root/contest-matching-model/data/jsonl_prepro_customs.jsonl',
            'seq_num': seq_num,
        }
    )
    customs_documents.append(doc)
    seq_num += 1

pprint(customs_documents[0])
print(customs_documents[0].page_content)
pprint(customs_documents[0].metadata)
# Out:
# Document(page_content='농가 사육용\r\nFor farm breeding\r\n말', metadata={'HS_CODE': '0101211000', 'INT_CODE': '11020101', 'source': '/root/contest-matching-model/data/jsonl_prepro_customs.jsonl', 'seq_num': 1})
# 농가 사육용
# For farm breeding
# 말
# {'HS_CODE': '0101211000',
#  'INT_CODE': '11020101',
#  'seq_num': 1,
#  'source': '/root/contest-matching-model/data/jsonl_prepro_customs.jsonl'}

# %% [markdown]
# # English-to-Korean translation

# %%
text_dup = text_prepro.drop_duplicates(subset='DSC').reset_index(drop=True)
text_dup
# Out:
#          ID  CODE                                                DSC
# 0         1  4520  automotive repair shops, nec  specialized auto...
# 1         2  0149  general farms, primarily animals, nsk  derives...
# 2         3  4630  fish and seafoods  the wholesale distribution ...
# 3         4  4510  new and used car dealers, nsk  manufactures a ...
# 4         4  2930  automotive stampings, nsk  manufacturing autom...
# ...     ...   ...                                                ...
# 1713  10634  4669  printing and writing paper, nsk  the wholesale...
# 1714  10635  1410  leather and sheep-lined clothing  manufacturin...
# 1715  10636  4652  electronic parts and equipment, nec, nsk  the ...
# 1716  10642  1104  bottled and canned soft drinks, nsk  manufactu...
# 1717  10644  2410  blast furnaces and steel mills, nsk  manufactu...
#
# [1718 rows x 3 columns]

# %%
chat = ChatUpstage(
    api_key=UPSTAGE_API_KEY, 
    model="solar-1-mini-translate-enko"
)

file_path = '../data/jsonl_enko_text.jsonl'
with open(file_path, 'a') as file:
    for idx in range(text_dup.shape[0]):
        message = text_dup.loc[idx, 'DSC']
        response = chat.invoke(message)

        output = {
            "ID": text_dup.loc[idx, 'ID'], 
            "CODE": text_dup.loc[idx, 'CODE'], 
            "DSC": response.content
        }
        file.write(f'{json.dumps(output, ensure_ascii=False)}\n')

        print('-----' * 7)
        print(f'ENG: {message}\nKOR: {response.content}')
# Out:
# -----------------------------------
# ENG: automotive repair shops, nec  specialized automotive repair, not elsewhere classified, such as fuel service carburetor repair, brake relining, front-end and wheel alignment, and radiator repair. motor vehicle repair and maintenance auto brake lining, installation other automotive mechanical and electrical repair and maintenance maintenance and repair of motor vehicles maintenance and repair of motor vehicles maintenance and repair of motor vehiclesother automotive repair and maintenance
# KOR: 자동차 수리점, nec  연료 서비스 기화기 수리, 브레이크 리닝, 프론트 엔드 및 휠 정렬, 라디에이터 수리 등 기타 자동차 수리 및 유지 보수 자동차 수리 및 유지 보수 자동차 브레이크 라이닝, 설치 기타 자동차 기계 및 전기 수리 및 유지 보수 자동차 유지 보수 및 수리 자동차 유지 보수 및 수리 자동차 기타 자동차 수리 및 유지 보수
# -----------------------------------
# ENG: general farms, primarily animals, nsk  derives 50 percent or more of its total value  of sales of agricultural products from livestock and animal specialties and their products, but less than 50 percent from products of any single three-digit industry group. crop and animal production general farms, primarily animals all other animal production mixed farming raising of other animals mixed farmingother livestock farming not elsewhere classified
# KOR: 일반농가, 주로 동물, nsk 는 농업 생산품의 총 가치  중 50 퍼센트 이상의 가축 및 동물 특산품 및 그 제품에서 파생 되지만 어떤 단일 3 자리 산업 그룹의 제품에서 50 퍼센트 미만이다. 농작물 및 동물 생산 일반농가, 주로 동물 기타 모든 동물 생산 혼합 농업 기타 동물 사육 혼합 농업기타 축산 기타 분류되지 않은 축산
# -----------------------------------
# ENG: fish and seafoods  the wholesale distribution but not packaging of fresh, cured, or frozen fish and seafoods, except canned or packaged frozen. grocery wholesale seafoods fish and seafood merchant wholesalers wholesale of other food, including fish, crustaceans and molluscs wholesale of food, beverages and tobacco wholesale of other food, including fish, crustaceans and molluscsfish and seafood wholesaling
# KOR: 담배 및 주류 도매업  담배 및 주류 도매업 도매사업체 담배 및 주류 도매업중분류사업체 담배 및 주류 도매업소분류사업체 담배 및 주류 도매업대분류사업체 담배 및 주류 도매업세분류사업체 담배 및 주류 도매업초분류사업체 담배 및 주류 도매업
# -----------------------------------
# ENG: new and used car dealers, nsk  manufactures a range of vehicles under its fiat and chrysler brands, including jeep, ram, dodge, alfa romeo, and abarth at 45 plants in the us and mexico. it ships about 2.5 million vehicles every year. it also features its parent's trademarked mopar motor parts automobile parts and service brand which carries more than 500,000 parts, options, and accessories for vehicle customization. motor vehicle and parts dealers automobiles, new and used new car dealers sale of cars and light motor vehicles sale of motor vehicles sale of cars and light motor vehiclesmotor vehicle retailing
# KOR: 신차 및 중고차 딜러, nsk  피아트 및 크라이슬러 브랜드로 미국에서 45개 공장에서 지프, 램, 닷지, 알파 로미오, 아바르 등 다양한 차량을 제조한다. 매년 약 250만 대의 차량을 출하한다. 또한 차량 맞춤화를 위한 50만 개 이상의 부품, 옵션 및 액세서리를 보유한 모회사의 상표인 mopar 모터 부품 자동차 부품 및 서비스 브랜드를 특징으로 한다. 자동차 및 부품 딜러 자동차, 신차 및 중고차 신차 딜러 자동차 및 경차 판매 자동차 및 경차 판매자동차 소매업
# -----------------------------------
# ENG: automotive stampings, nsk  manufacturing automotive stampings, such as body parts, hubs, and trim. motor vehicle parts manufacturing automotive stampings motor vehicle metal stamping forging, pressing, stamping and roll-forming of metal; powder metallurgy manufacture of parts and accessories for motor vehicles forging, pressing, stamping and roll-forming of metal; powder metallurgysheet metal product manufacturing (except metal structural and container products)
# KOR: 자동차 스탬핑, nsk  제조 자동차 스탬핑, 예를 들어 차체 부품, 허브 및 트림. 자동차 부품 제조 자동차 스탬핑 자동차 금속 스탬핑 단조, 압착, 스탬핑 및 금속의 롤 포밍; 파우더 메탈 제조 자동차 부품 및 액세서리 단조, 압착, 스탬핑 및 금속의 롤 포밍; 파우더 메탈판금 제품 제조 (금속 구조 및 컨테이너 제품 제외)
# -----------------------------------
# ENG: furniture stores  the retail sale of household furniture. these stores may also sell home furnishings, major appliances, and floor coverings. home furnishings retail furniture stores furniture stores retail sale of furniture, lighting equipment and other household articles (other than musical instruments) n.e.c., in specialised stores retail sale of electrical household appliances, furniture, lighting equipment and other household articles in specialized stores retail sale of furniture, lighting equipment and other household articles in specialised storesfurniture retailing
# KOR: 가구점  가정용 가구의 소매 판매. 이 상점들은 가정용 가구, 주요 가전 제품 및 바닥재를 판매할 수도 있습니다. 가정용 가구 소매 가구점 가구점 가구, 조명 장비 및 기타 가정용 물품 (악기 제외)의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품의 소매 판매 가구점 가구, 조명 장비 및 기타 가정용 물품
# -----------------------------------
# ENG: industrial machinery and equipment  the wholesale distribution of industrial machinery and equipment, not elsewhere classified. machinery wholesale industrial machinery and equipment industrial machinery and equipment merchant wholesalers wholesale of other machinery and equipment wholesale of other machinery and equipment wholesale of other machinery, equipment and suppliesother specialised industrial machinery and equipment wholesaling
# KOR: 산업용 기계 및 장비  기타 분류되지 않은 산업용 기계 및 장비 도매업. 기계 도매업 산업용 기계 및 장비 산업용 기계 및 장비 상인 도매업 기타 기계 및 장비 도매업 기타 기계 및 장비 도매업 기타 기계, 장비 및 용품 도매업기타 전문 산업용 기계 및 장비 도매업
# -----------------------------------
# ENG: metal cans, nsk  manufacturing metal cans from purchased materials. metal products manufacturing food and beverage containers metal can manufacturing manufacture of light metal packaging manufacture of other fabricated metal products n.e.c. manufacture of light metal packagingother metal container manufacturing
# KOR: 금속캔, nsk  구입한 자재를 금속캔으로 제조함. 금속제품제조식품 및 음료 용기 금속캔 제조 경금속 포장재 제조 기타 금속 가공제품 제조업n.e.c. 경금속 포장재제조기타 금속용기 제조업
# -----------------------------------
# ENG: sporting and athletic goods, nec the coleman company makes what it takes to be a happy camper. as a leading manufacturer of outdoor recreation gear, it produces coolers, backpacks, tents, sleeping bags, air mattresses, lanterns, grills, life vests, and floats, among other items, which are sold under the wake vest, helium, puddle jumper, mad dog gear, sevylor, and stearns brands. coleman operates sales offices and distribution facilities worldwide and sells its products mainly through mass merchandisers, home centers, and other retail stores, as well as through its website and a network of about a dozen coleman factory outlet stores. founded in 1900, coleman is owned by jarden corporation. miscellaneous manufacturing camping equipment and supplies sporting and athletic goods manufacturing manufacture of sports goods manufacture of sports goods manufacture of sports goodstoy, sporting and recreational product manufacturing
# KOR: 스포츠 및 운동용품, nec 콜맨 컴퍼니는 행복한 캠퍼가 되기 위해 필요한 것을 만듭니다. 야외 레크리에이션 장비의 선도적인 제조업체로서, 쿨러, 배낭, 텐트, 침낭, 에어 매트리스, 랜턴, 그릴, 구명조끼 및 부력 장치 등 다양한 제품을 생산하며, 웨이크 베스트, 헬륨, 퍼들 점퍼, 매드 독 기어, 세빌로 및 스타른스 브랜드로 판매됩니다. 콜맨은 전 세계적으로 영업 사무소와 유통 시설을 운영하며, 주로 대량 판매점, 홈 센터 및 기타 소매점, 그리고 웹사이트와 약 12개의 콜맨 공장 아울렛 매장을 통해 제품을 판매합니다. 1900년에 설립된 콜맨은 자든 코퍼레이션이 소유하고 있습니다. 기타 제조업 캠핑 장비 및 용품 스포츠 및 운동용품 제조업 스포츠 용품 제조업 스포츠 용품 제조업 스포츠 용품 제조업완구, 스포츠 및 레크리에이션 제품 제조업
# -----------------------------------
# ENG: power-driven handtools, nsk  create a lot of buzz. the company, which is the us arm of germany-based stihl international, makes chainsaws, edgers, leaf blowers, trimmers, and other landscaping tools and components. stihl incorporated markets its products, which are protected by more than 1,000 patents, through a dozen corporate distribution centers and independent wholesalers. its tools are sold by more than 9,000 independent tool and hardware retailers you won't find them at big box home stores throughout the us and exported to more than 90 countries. the us-based marketing and manufacturing unit was established in 1974. machinery and equipment manufacturing chain saws, portable power-driven handtool manufacturing manufacture of power-driven hand tools manufacture of power-driven hand tools manufacture of power-driven hand toolsmachine tool and parts manufacturing
# KOR: 동력 구동 핸드 툴, nsk  많은 화제를 만들어냅니다. 독일에 본사를 둔 stihl international의 미국 지사인 이 회사는 전기톱, 에지, 낙엽 송풍기, 트리머 및 기타 조경 도구 및 구성품을 만듭니다. stihl incorporated는 1,000개 이상의 특허로 보호되는 제품을 12개의 기업 유통 센터와 독립 도매상을 통해 마케팅합니다. 그 도구는 미국 전역의 대형 박스 홈 스토어에서 찾을 수 없으며 9,000개 이상의 독립 도구 및 하드웨어 소매업체에서 판매됩니다. 미국 기반 마케팅 및 제조 부문은 1974년에 설립되었습니다. 기계 및 장비 제조 전기톱, 휴대용 동력 구동 핸드 도구 제조 동력 구동 핸드 도구 제조 동력 구동 핸드 도구 제조기계 공구 및 부품 제조
# -----------------------------------
# ENG: fresh fruits and vegetables  the wholesale distribution of fresh fruits and vegetables. grocery wholesale fruits, fresh fresh fruit and vegetable merchant wholesalers wholesale of fruit and vegetables wholesale of food, beverages and tobacco wholesale of fruit and vegetablesfruit and vegetable wholesaling
# KOR: 신선한 과일과 채소  신선한 과일과 채소의 도매 유통. 식료품 도매 과일, 신선한 신선한 과일과 채소 상인 도매 과일 및 채소 도매 식품, 음료 및 담배 도매 과일 및 채소 도매
# -----------------------------------
# ENG: motor vehicle supplies and new parts  the wholesale distribution of motor vehicle supplies, accessories, tools, and equipment; and new motor vehicle parts. motor vehicle wholesale automotive supplies and parts motor vehicle supplies and new parts merchant wholesalers wholesale trade of motor vehicle parts and accessories sale of motor vehicle parts and accessories wholesale trade of motor vehicle parts and accessoriesmotor vehicle new parts wholesaling
# KOR: 자동차용 신품 부품 및 용품  자동차용 용품, 액세서리, 도구 및 장비; 신품 자동차 부품을 도매로 유통하는 산업. 자동차 도매 자동차 용품 및 부품 자동차 용품 및 신품 부품 상품 도매 자동차 부품 및 액세서리 판매 자동차 부품 및 액세서리 도매 자동차 부품 및 액세서리 도매자동차 신품 부품 도매
# -----------------------------------
# ENG: chemicals and allied products, nec  the wholesale distribution of chemicals and allied products, not elsewhere classified, such as acids, industrial and heavy chemicals, dyestuffs, industrial salts, rosin, and turpentine. chemical wholesale detergents other chemical and allied products merchant wholesalers wholesale of chemical products wholesale of waste and scrap and other products n.e.c. wholesale of chemical productsindustrial and agricultural chemical product wholesaling
# KOR: 화학 및 관련제품, 네c  산, 공업용 및 중화학제품, 염료, 공업용 소금, 로진, 그리고 테레핀유와 같은 화학약품 및 관련 제품의 도매 유통업. 화학 도매세제 기타 화학 및 관련 제품 상품 도매업 화학제품 도매업 화학제품의 도매업 폐기물 및 스크랩 및 기타 제품 n.e.c. 의 도매업 화학제품의 도매업산업용 및 농업용 화학제품 도매업
# -----------------------------------
# ENG: electronic parts and equipment, nec, nsk  the wholesale distribution of electronic parts and electronic communications equipment, not elsewhere classified, such as telephone and telegraphic equipment; radio and television broadcasting and communications equipment; and intercommunications equipment. electronics wholesale electronic parts and equipment, nec other electronic parts and equipment merchant wholesalers wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and partsother electrical and electronic goods wholesaling
# KOR: 전자부품 및 장비, nec, nsk  전화 및 전신 장비; 라디오 및 텔레비전 방송 및 통신 장비; 및 상호 통신 장비와 같은 전자 부품 및 전자 통신 장비, nec의 도매 유통. 전자 제품 도매 전자 부품 및 장비, nec 기타 전자 부품 및 장비 상품 도매 전자 및 통신 장비 및 부품 도매 전자 및 통신 장비 및 부품 도매 전자 및 통신 장비 및 부품기타 전기 및 전자 제품 도매
# -----------------------------------
# ENG: misc. apparel and accessory stores,nsk  the retail sale of specialized lines of apparel and accessories, not elsewhere classified, such as uniforms, bathing suits, raincoats, riding apparel, sports apparel, umbrellas, wigs, and toupees. this industry also includes custom tailors primarily engaged in making and selling men's and women's clothing, except fur apparel. clothing and apparel stores uniforms other clothing stores retail sale of clothing in specialised stores retail sale of clothing, footwear and leather articles in specialized stores retail sale of clothing in specialised storesother personal accessory retailing
# KOR: 기타 의류 및 액세서리 매장,nsk  제복, 수영복, 우의, 승마복, 스포츠복, 우산, 가발 및 인조두피 등 기타 분류되지 않은 전문 의류 및 액세서리의 소매 판매. 이 산업에는 모피 의류를 제외한 남성과 여성 의류를 주로 제작하고 판매하는 맞춤 양복점도 포함된다. 의류 및 액세서리 매장 제복 기타 의류 매장 전문점에서 의류 소매 판매 전문점에서 의류, 신발 및 가죽 제품 소매 판매 전문점에서 의류 소매 판매기타 개인 액세서리 소매업
# -----------------------------------
# ENG: meat packing plants, nsk  the slaughtering, for their own account or on a contract basis for the trade, of cattle, hogs, sheep, lambs, and calves for meat to be sold or to be used on the same premises in canning, cooking, curing, and freezing, and in making sausage, lard, and other products. this includes slaughtering horses for human consumption. food manufacturing meat by-products, from meat slaughtered on site animal (except poultry) slaughtering processing and preserving of meat processing and preserving of meat processing and preserving of meat and production of meat productsmeat processing
# KOR: 육류 포장 공장, nsk  현장에서 도축 된 소, 돼지, 양, 양, 송아지의 고기, 통조림, 요리, 경화 및 냉동, 소시지, 라드 및 기타 제품 제조를 위해 동물을 도살하는 것. 이것은 인간의 소비를 위해 말을 도살하는 것을 포함합니다. 식품 제조 육류 부산물, 현장에서 도축 된 육류에서 동물 (가금류 제외) 도축 육류의 가공 및 보존 육류의 가공 및 보존 육류의 가공 및 보존 및 육류 제품의 생산육류 가공
# -----------------------------------
# ENG: poultry hatcheries, nsk  operating poultry hatcheries on their own account or on a contract or fee basis. crop and animal production poultry hatcheries, nec poultry hatcheries raising of poultry raising of poultry raising of poultrypoultry farming (meat)
# KOR: 가금류 사육장, nsk  자신의 계정 또는 계약 또는 수수료 기준으로 운영되는 가금류 사육장. 작물 및 동물 생산 가금류 사육장, nec 가금류 사육장 가금류 사육장 가금류 사육장 가금류 사육장 (육류)
# -----------------------------------
# ENG: groceries, general line, nsk  the wholesale distribution of a general line of groceries. grocery wholesale food brokers general line grocery merchant wholesalers non-specialised wholesale of food, beverages and tobacco wholesale of food, beverages and tobacco wholesale of food, beverages and tobaccogeneral line grocery wholesaling
# KOR: 식료품, 일반 라인, nsk  식료품, 일반 라인의 도매 유통. 식료품 도매 식품 중개인 일반 라인 식료품 상인 도매업 식품, 음료 및 담배의 비전문적인 도매 식품, 음료 및 담배의 도매 식품, 음료 및 담배의 도매 일반 라인 식료품 도매
# -----------------------------------
# ENG: poultry hatcheries, nsk  operating poultry hatcheries on their own account or on a contract or fee basis. crop and animal production chicken hatchery poultry hatcheries raising of poultry raising of poultry raising of poultrypoultry farming (meat)
# KOR: 가금류 부화장, nsk  자신의 계정 또는 계약 또는 수수료 기반으로 가금류 부화장을 운영합니다. 작물 및 동물 생산 닭 부화장 가금류 부화장 가금류 사육 가금류 사육 가금류 사육가금류 사육 (육류)
# -----------------------------------
# ENG: nondurable goods, nec, nsk  the wholesale distribution of non-durable goods, not elsewhere classified, such as art goods, industrial yarns, textile bags, and bagging and burlap. nonclassifiable establishments general merchandise, non-durable other miscellaneous nondurable goods merchant wholesalers nonclassifiable establishments non-specialized wholesale trade non-specialised wholesale tradenonclassifiable establishments
# KOR: 비내구소비재, nec, nsk  예술품, 산업용 실, 섬유제 가방, 자루 및 마대와 같은 그 외 기타 분류 안된 비내구소비재 도매업. 분류 안 된 업소 일반상품, 비내구 기타 기타 비내구소비재 상품 도매업 분류 안 된 업소 비전문 도매업 비전문 도매업분류 안 된 업소
# -----------------------------------
# ENG: industrial machinery and equipment  the wholesale distribution of industrial machinery and equipment, not elsewhere classified. machinery wholesale industrial machine parts industrial machinery and equipment merchant wholesalers wholesale of other machinery and equipment wholesale of other machinery and equipment wholesale of other machinery, equipment and suppliesother specialised industrial machinery and equipment wholesaling
# KOR: 산업용 기계 및 장비  기타에 분류되지 않은 산업용 기계 및 장비의 도매 유통. 기계 도매 산업용 기계 부품 산업용 기계 및 장비 상인 도매 기타 기계 및 장비 도매 기타 기계 및 장비 도매 기타 기계, 장비 및 용품기타 특수 산업용 기계 및 장비 도매
# -----------------------------------
# ENG: packaged frozen goods  the wholesale distribution of packaged quick-frozen vegetables, juices, meats, fish, poultry, pastries, and other "deep freeze" products. grocery wholesale meat, frozen: packaged packaged frozen food merchant wholesalers non-specialised wholesale of food, beverages and tobacco wholesale of food, beverages and tobacco wholesale of food, beverages and tobaccoother grocery wholesaling
# KOR: 포장된 냉동 상품  포장된 급속 냉동 야채, 주스, 육류, 어류, 가금류, 제과류 및 기타 "심층 냉동" 제품의 도매 유통. 식료품 도매 육류, 냉동: 포장된 포장된 냉동 식품 상인 도매의 비전문 도매의 식품, 음료 및 담배 도매의 식품, 음료 및 담배 도매의 식품, 음료 및 담배기타 식료품 도매
# -----------------------------------
# ENG: eating places filipinos looking to get their fast-food jollies can turn to this happy bee. jollibee foods is the leading operator of quick-service restaurants in the philippines, with more than 1,500 outlets encompassing about a half dozen different concepts. its flagship jollibee chain features a menu of fast-food staples hamburgers, hot dogs, and fried chicken along with asian spring rolls, spaghetti, soups, and ice cream. the company also operates such chains as greenwich pizza, chowking and yonghe king quick-service asian food, and red ribbon bakery items.?in addition to its domestic operations, jollibee has restaurants in about six other countries. restaurants and bars fast-food restaurant, chain limited-service restaurants restaurants and mobile food service activities restaurants and mobile food service activities restaurants and mobile food service activitiescafes, restaurants and takeaway food services
# KOR: eating places 필리피노들이 패스트푸드를 즐기기 위해 찾을 수 있는 행복한 벌. 졸리비 푸드는 필리핀에서 가장 큰 퀵 서비스 레스토랑 운영업체로, 약 1,500개 이상의 매장을 보유하고 있으며, 약 6개의 다른 컨셉을 포괄하고 있다. 그 주력 졸리비 체인은 햄버거, 핫도그, 프라이드 치킨과 같은 패스트푸드의 주요 메뉴와 아시안 스프링 롤, 스파게티, 수프, 아이스크림을 특징으로 한다. 이 회사는 또한 그린위치 피자, 차우킹과 용헤 킹 퀵 서비스 아시안 푸드, 레드 리본 베이커리 아이템과 같은 체인을 운영하고 있다.?국내 운영 외에도 졸리비는 약 6개의 다른 국가에 레스토랑을 보유하고 있다. 레스토랑 및 바 패스트푸드 레스토랑, 체인 제한 서비스 레스토랑 레스토랑 및 모바일 음식 서비스 활동 레스토랑 및 모바일 음식 서비스 활동 레스토랑 및 모바일 음식 서비스 활동카페, 레스토랑 및 테이크아웃 음식 서비스
# -----------------------------------
# ENG: general government, nec, nsk  providing general support for government, which include personnel, auditing, procurement services, and building management services, and other general government establishments which cannot be classified in other industries. executive and legislature general government, nec other general government support general public administration activities general public administration activities general public administration activitiespublic administration
# KOR: 일반정부, nec, nsk  인사, 감사, 조달 서비스, 건물 관리 서비스 등을 제공하는 일반 지원을 제공하는 일반 정부, 기타 산업에 분류할 수 없는 일반 정부 기관을 포함합니다. 행정부 및 입법부 일반정부, nec 기타 일반정부 지원 일반 공공행정 활동 일반 공공행정 활동 일반 공공행정 활동공공행정
# -----------------------------------
# ENG: meats and meat products, nsk  the wholesale distribution of fresh, cured, and processed but not canned meats and lard. grocery wholesale meats and meat products meat and meat product merchant wholesalers wholesale of meat and meat products wholesale of food, beverages and tobacco wholesale of meat and meat productsmeat, poultry and smallgoods wholesaling
# KOR: 육류 및 육류 제품, nsk  신선, 훈제, 가공 그러나 통조림되지 않은 육류 및 라드의 도매 유통. 식료품 도매 육류 및 육류 제품 육류 및 육류 제품 상인 도매상 육류 및 육류 제품의 도매업 식료품, 음료 및 담배의 도매업 육류 및 육류 제품의 도매업육류, 가금류 및 소시지 도매업
# -----------------------------------
# ENG: groceries and related products, nec, nsk  the wholesale distribution of soft drinks, and in bottling and distributing natural spring and mineral waters, are classified in this industry. grocery wholesale groceries and related products, nec other grocery and related products merchant wholesalers wholesale of other food, including fish, crustaceans and molluscs wholesale of food, beverages and tobacco wholesale of food, beverages and tobaccoother grocery wholesaling
# KOR: 식료품 및 관련 제품, 그 밖의, nsk  청량 음료의 도매 유통 및 천연 샘물 및 미네랄 워터의 병입 및 유통은 이 산업에 분류됩니다. 식료품 도매 식료품 및 관련 제품, 그 밖의 기타 식료품 및 관련 제품 상인 도매업자 어류, 갑각류 및 연체 동물을 포함한 기타 식품 도매업자 식품, 음료 및 담배 도매업자 식품, 음료 및 담배기타 식료품 도매업
# -----------------------------------
# ENG: groceries and related products, nec, nsk  the wholesale distribution of soft drinks, and in bottling and distributing natural spring and mineral waters, are classified in this industry. grocery wholesale canned goods: fruit, vegetables, seafood, meats, etc. other grocery and related products merchant wholesalers wholesale of other food, including fish, crustaceans and molluscs wholesale of food, beverages and tobacco wholesale of food, beverages and tobaccoother grocery wholesaling
# KOR: 식료품 및 관련 제품, 기타, nsk  청량 음료의 도매 유통 및 천연 샘물 및 미네랄 워터의 병입 및 유통은 이 산업으로 분류된다. 식료품 도매 통조림 식품: 과일, 야채, 해산물, 육류 등 기타 식료품 및 관련 제품 상품 도매업 도매의 기타 식품, 생선, 갑각류 및 연체 동물 도매 식료품 및 관련 제품, 기타, nsk  식료품 및 관련 제품, 기타, nsk
# -----------------------------------
# ENG: fish and seafoods  the wholesale distribution but not packaging of fresh, cured, or frozen fish and seafoods, except canned or packaged frozen. grocery wholesale fish and seafoods fish and seafood merchant wholesalers wholesale of other food, including fish, crustaceans and molluscs wholesale of food, beverages and tobacco wholesale of other food, including fish, crustaceans and molluscsfish and seafood wholesaling
# KOR: 생선 및 해산물  통조림이나 포장된 냉동제품은 제외하고 신선, 염장 또는 냉동된 생선과 해산물의 도매 유통이지만 포장은 하지 않음. 식료품 도매 생선 및 해산물 생선 및 해산물 상품 도매상 생선, 갑각류 및 연체동물을 포함한 기타 식품의 도매 생선, 갑각류 및 연체동물을 포함한 기타 식품의 도매 식품, 음료 및 담배의 도매 생선, 갑각류 및 연체동물을 포함한 기타 식품의 도매 생선 및 해산물 도매
# -----------------------------------
# ENG: sausages and other prepared meats  manufacturing sausages, cured meats, smoked meats, canned meats, frozen meats, and other prepared meats and meat specialties, from purchased carcasses and other materials. prepared meat plants operated by packing houses as separate establishments are also included in this industry. food manufacturing pork, cured: from purchased meat meat processed from carcasses production of meat and poultry meat products processing and preserving of meat production of meat and poultry meat productsmeat processing
# KOR: sausages and other prepared meats  구입한 도체 및 기타 재료로부터 소시지, 염장육, 훈제육, 통조림육, 냉동육 및 기타 조리된 육류 및 육류 특산품을 제조한다. 포장업체가 별도의 시설로 운영하는 조리육 공장도 이 산업에 포함된다. 식품 제조 돼지고기, 염장: 구입한 고기에서 도체에서 가공한 고기 육류 및 가금류 육류 제품의 생산 육류 및 가금류 육류 제품의 가공 및 보존 육류 및 가금류 육류 제품의 생산육류 가공
# -----------------------------------
# ENG: new and used car dealers, nsk  the retail sale of new automobiles or new and used automobiles. these establishments frequently maintain repair departments and carry stocks of replacement parts, tires, batteries, and automotive accessories. these establishments also frequently sell pickups and vans at retail. motor vehicle and parts dealers new and used car dealers new car dealers sale of cars and light motor vehicles sale of motor vehicles sale of cars and light motor vehiclesmotor vehicle retailing
# KOR: 신차 및 중고차 딜러, nsk  신차 또는 신차 및 중고차의 소매 판매. 이러한 업체는 수리 부서를 유지하고 교체 부품, 타이어, 배터리 및 자동차 액세서리의 재고를 보유하는 경우가 많습니다. 이러한 업체는 또한 픽업 및 밴을 소매로 판매하는 경우가 많습니다. 자동차 및 부품 딜러 신차 및 중고차 딜러 신차 딜러 자동차 및 경차 판매 자동차 및 경차 판매자동차 소매업
# -----------------------------------
# ENG: motor vehicles and car bodies  manufacturing or assembling complete passenger automobiles, trucks, commercial cars and buses, and special purpose motor vehicles which are for highway use. this also includes the manufacturing of chassis and passenger car bodies. motor vehicle manufacturing motor vehicles and car bodies automobile manufacturing manufacture of motor vehicles manufacture of motor vehicles manufacture of motor vehicles, trailers and semi-trailersmotor vehicle and motor vehicle part manufacturing
# KOR: motor vehicles and car bodies  제조 또는 조립하는 완전한 승용차, 트럭, 상업용 자동차 및 버스, 그리고 고속도로 사용을 위한 특수 목적의 모터 차량. 이는 또한 섀시 및 승용차 차체의 제조를 포함합니다. 모터 차량 제조 모터 차량 및 차체 자동차 제조 모터 차량 제조 모터 차량 제조 모터 차량, 트레일러 및 세미 트레일러 제조모터 차량 및 모터 차량 부품 제조
# -----------------------------------
# ENG: instruments to measure electricity  manufacturing instruments for measuring the characteristics of electricity and electrical signals, such as voltmeters, ammeters, wattmeters, watt-hour meters, demand meters, and equipment for testing the electrical characteristics of electrical, radio, and communication circuits and of internal combustion engines. electromedical and control instruments manufacturing electrical energy measuring equipment instrument manufacturing for measuring and testing electricity and electrical signals manufacture of electronic instruments and appliances for measuring, testing, and navigation, except industrial process control equipment manufacture of measuring, testing, navigating and control equipment manufacture of instruments and appliances for measuring, testing and navigationother professional and scientific equipment manufacturing
# KOR: 전기를 측정하는 기기  전압계, 전류계, 와트계, 와트시계, 수요계 및 전기, 라디오 및 통신회로 및 내연기관의 전기적 특성을 시험하는 장비와 같은 전기 및 전기신호의 특성을 측정하는 기기를 제조. 전기의료용 및 제어용 기기 전기 에너지 측정 장비 기기를 제조하는 기기 제조 전기 및 전기신호의 측정과 시험을 위한 기기 및 장비 제조 산업용 공정 제어 장비를 제외한 측정, 시험, 항해용 전자기기 및 기구 제조 측정, 시험, 항해 및 제어장비 기기를 제조하는 기기 기타 전문 및 과학 장비 기기 제조
# -----------------------------------
# ENG: surgical and medical instruments  manufacturing medical, surgical, ophthalmic, and veterinary instruments and apparatus. medical equipment and supplies surgical and medical instruments surgical and medical instrument manufacturing manufacture of medical and dental instruments and supplies manufacture of medical and dental instruments and supplies manufacture of medical and dental instruments and suppliesmedical and surgical equipment manufacturing
# KOR: 외과및의료용기기 제조업 의료, 외과용, 안과용 및 수의용 기기 제조업. 의료용 기기 및 용품 외과및의료용기기 제조업 외과및의료용기기 제조업 의료 및 치과용 기기 제조업 의료 및 치과용 기기 제조업 의료 및 치과용 기기 제조업의료 및 정밀기기 제조업
# -----------------------------------
# ENG: pharmaceutical preparations : 1 manufacturing bulk organic and inorganic medicinal chemicals and their derivatives and 2 processing grading, grinding, and milling bulk botanical drugs and herbs. this also includes manufacturing agar-agar and similar products of natural origin, endocrine products, manufacturing or isolating basic vitamins, and isolating active medicinal principals such as alkaloids from botanical drugs and herbs. pharmaceutical manufacturing medicinals and botanicals medicinal and botanical manufacturing manufacture of basic pharmaceutical products manufacture of pharmaceuticals, medicinal chemical and botanical products manufacture of basic pharmaceutical productshuman pharmaceutical and medicinal product manufacturing
# KOR: 제약 제조 : 1 제조 대량 유기 및 무기 약용 화학 물질 및 그 파생 제품과 2 가공 대량 식물성 약물 및 허브를 등급, 연마 및 밀링하는 것과 같은 작업을 수행합니다. 이것은 또한 천연 기원의 한천 및 유사한 제품, 내분비 제품, 기본 비타민 제조 또는 격리, 식물성 약물 및 허브에서 알칼로이드와 같은 활성 의약 원리를 분리하는 것을 포함합니다. 제약 제조 의약품 및 식물성 의약품 및 식물성 제조 기본 의약품 제조 제약, 의약품 화학 및 식물성 제품 제조 기본 의약품 제조인간용 의약품 및 의약품 제조
# -----------------------------------
# ENG: medicinals and botanicals, nsk : 1 manufacturing bulk organic and inorganic medicinal chemicals and their derivatives and 2 processing grading, grinding, and milling bulk botanical drugs and herbs. this also includes manufacturing agar-agar and similar products of natural origin, endocrine products, manufacturing or isolating basic vitamins, and isolating active medicinal principals such as alkaloids from botanical drugs and herbs. pharmaceutical manufacturing penicillin: bulk, uncompounded medicinal and botanical manufacturing manufacture of basic pharmaceutical products manufacture of pharmaceuticals, medicinal chemical and botanical products manufacture of basic pharmaceutical productshuman pharmaceutical and medicinal product manufacturing
# KOR: 의약품 및 약초, nsk : 1 제조 대량 유기 및 무기 의약품 및 그 유도체 및 2 가공 등급, 연삭 및 밀링 대량 약초 약물 및 허브. 이것은 또한 천연 기원의 한천 및 유사한 제품, 내분비 제품 제조 또는 분리, 기본 비타민 제조 및 약초 약물 및 허브에서 알칼로이드와 같은 활성 의약품 원리 분리를 포함한다. 제약 제조 페니실린: 대량, 화합되지 않은 의약품 및 약초 제조 기본 의약품 제품 제조 의약품, 의약품 화학 및 약초 제품 제조 기본 의약품 제품 제조인간 의약품 및 의약품 제조
# -----------------------------------
# ENG: hand and edge tools, nec  manufacturing files and other hand and edge tools for metalworking, woodworking, and general maintenance. metal products manufacturing cutting dies, except metal cutting saw blade and handtool manufacturing manufacture of tools manufacture of cutlery, hand tools and general hardware manufacture of toolsother fabricated metal product manufacturing not elsewhere classified
# KOR: 수공구 및 날붙이, 기타 제조업 금속가공, 목재가공, 일반수리 등에 사용되는 수공구 및 날붙이 제조. 금속제품 제조업 절단용 다이, 금속절삭용 톱날을 제외한 절단용 다이 제조업 공구제조업 식기, 수공구 및 일반철물 제조업 공구기타직물제품 제조업 기타 분류 안 된 직물제품 제조업
# -----------------------------------
# ENG: pharmaceutical preparations  manufacturing, fabricating, or processing drugs in pharmaceutical preparations for human or veterinary use. the greater part of the products of these establishments are finished in the form intended for final consumption, such as ampoules, tablets, capsules, vials, ointments, medicinal powders, solutions, and suspensions. products of this industry consist of two important lines, namely: 1 pharmaceutical preparations promoted primarily to the dental, medical, or veterinary professions, and 2 pharmaceutical preparations promoted primarily to the public. pharmaceutical manufacturing pharmaceutical preparations pharmaceutical preparation manufacturing manufacture of pharmaceutical preparations manufacture of pharmaceuticals, medicinal chemical and botanical products manufacture of pharmaceutical preparationshuman pharmaceutical and medicinal product manufacturing
# KOR: 의약품 제조, 가공 또는 의약품 제조를 위한 의약품 제조, 가공 또는 가공. 이러한 시설의 제품의 대부분은 최종 소비를 위해 의도된 형태로 완성됩니다. 예를 들어, 앰플, 정제, 캡슐, 약병, 연고, 의약 분말, 용액 및 현탁액. 이 산업의 제품은 두 가지 중요한 라인으로 구성됩니다. 즉, 1 치과, 의료 또는 수의학 전문가에게 주로 홍보되는 의약품 제조, 2 주로 대중에게 홍보되는 의약품 제조. 의약품 제조 의약품 제조 의약품 제조 제조 의약품 제조, 의약품, 의약품 화학 및 식물 제품 제조 의약품 제조인간 의약품 및 의약품 제조
# -----------------------------------
# ENG: data processing and preparation  providing computer processing and data preparation services. the service may consist of complete processing and preparation of reports from data supplied by the customer or a specialized service, such as data entry or making data processing equipment available on an hourly or time-sharing basis. data processing data processing and preparation data processing, hosting, and related services data processing, hosting and related activities data processing, hosting and related activities data processing, hosting and related activitiescomputer system design and related services
# KOR: 자료처리 및 준비  컴퓨터 처리와 자료준비 서비스를 제공하는 것이다. 이 서비스는 고객이 공급한 자료로부터 보고서의 완전한 처리 및 준비로 구성될 수 있거나, 자료입력이나 자료처리 설비를 시간당 또는 시분할 방식으로 이용할 수 있게 하는 것과 같은 전문적인 서비스를 포함한다. 자료처리자료처리 및 준비 자료처리, 호스팅 및 관련 서비스 자료처리, 호스팅 및 관련 활동 자료처리, 호스팅 및 관련 활동 자료처리, 호스팅 및 관련 활동컴퓨터 시스템 설계 및 관련 서비스
# -----------------------------------
# ENG: fabricated rubber products, nec, nsk  manufacturing industrial rubber goods, rubberized fabrics, and vulcanized rubber clothing, and miscellaneous rubber specialties and sundries, not elsewhere classified. this also includes reclaiming rubber and rubber articles. rubber and plastic product manufacturing foam rubber all other rubber product manufacturing manufacture of other rubber products manufacture of other rubber products manufacture of other rubber productspolymer product and rubber product manufacturing
# KOR: 가공된 고무제품, 네크, nsk  제조 산업용 고무 제품, 고무화 직물 및 가황 고무 의류, 그리고 기타 고무 특수품 및 잡화, 기타 분류되지 않은 것. 이것은 또한 고무 및 고무 제품을 회수하는 것을 포함한다. 고무 및 플라스틱 제품 제조 발포 고무 기타 모든 고무 제품 제조 기타 고무 제품 제조 기타 고무 제품 제조고분자 제품 및 고무 제품 제조
# -----------------------------------
# ENG: custom computer programming services, nsk  providing computer programming services on a contract or fee basis. establishments of this industry perform a variety of additional services, such as computer software design and analysis; modifications of custom software; and training in the use of custom software. computer programming computer software development and applications custom computer programming services computer programming activities computer consultancy and computer facilities management activities computer programming activitiescomputer system design and related services
# KOR: 맞춤 컴퓨터 프로그래밍 서비스, nsk  계약 또는 수수료 기준의 컴퓨터 프로그래밍 서비스를 제공한다. 이 산업의 사업체들은 컴퓨터 소프트웨어 설계 및 분석, 맞춤 소프트웨어의 수정, 맞춤 소프트웨어 사용에 대한 교육 등과 같은 다양한 추가 서비스를 수행한다. 컴퓨터 프로그래밍 컴퓨터 소프트웨어 개발 및 응용 맞춤 컴퓨터 프로그래밍 서비스 컴퓨터 프로그래밍 활동 컴퓨터 컨설팅 및 컴퓨터 시설 관리 활동 컴퓨터 프로그래밍 활동컴퓨터 시스템 설계 및 관련 서비스
# -----------------------------------
# ENG: space vehicle equipment, nec, nsk  manufacturing guided missile and space vehicle parts and auxiliary equipment, not elsewhere classified. this industry also includes establishments owned by manufacturers of guided missile and space vehicle parts and auxiliary equipment, not elsewhere classified, and primarily engaged in research and development on such products, whether from enterprise funds or on a contract or fee basis. guided missile and space vehicle manufacturing airframe assemblies, guided missiles other guided missile and space vehicle parts and auxiliary equipment manufacturing manufacture of air and spacecraft and related machinery manufacture of air and spacecraft and related machinery manufacture of air and spacecraft and related machineryaircraft manufacturing and repair services
# KOR: 우주선장비, 기타, nsk  유도탄 및 우주선 부품 및 부대설비 제조업 중 기타에 분류되지 않는 제조업. 이 항목에는 유도탄 및 우주선 부품 및 부대설비 제조업 중 기타에 분류되지 않는 제조업자가 소유하고 있고, 주로 기업 자체자금으로, 또는 도급 또는 수주 방식으로 이러한 제품에 대한 연구개발을 행하는 사업체도 포함된다. 유도탄 및 우주선 제조업 항공기용 기체조립품, 유도탄 기타 유도탄 및 우주선 부품 및 부대설비 제조업 항공기용 기체조립품, 유도탄
# -----------------------------------
# ENG: turbines and turbine generator sets, nsk  manufacturing steam turbines; hydraulic turbines; gas turbines, except aircraft; and complete steam, gas, and hydraulic turbine generator set units. also included in this industry are the manufacture of wind and solar powered turbine generators and windmills for generating electric power. machinery and equipment manufacturing turbines and turbine generator sets and parts turbine and turbine generator set units manufacturing manufacture of engines and turbines, except aircraft, vehicle and cycle engines manufacture of engines and turbines, except aircraft, vehicle and cycle engines manufacture of engines and turbines, except aircraft, vehicle and cycle enginesother machinery and equipment manufacturing not elsewhere classified
# KOR: 터빈 및 터빈발전기 세트, nsk  제조 스팀터빈; 수력터빈; 항공기용을 제외한 가스 터빈; 및 완성된 스팀, 가스, 수력 터빈 발전기 세트 단위. 또한 이 산업에는 전기 발전용 풍력 및 태양열 터빈 발전기와 풍차 제조가 포함된다. 기계 및 장비 제조 터빈 및 터빈발전기 세트 및 부품 터빈 및 터빈발전기 세트 단위 제조 항공기용, 차량 및 사이클용 엔진을 제외한 엔진 및 터빈 제조 항공기용, 차량 및 사이클용 엔진을 제외한 엔진 및 터빈 제조기타 기계 및 장비 제조 분류되지 않은 기타 기계 및 장비
# -----------------------------------
# ENG: blowers and fans  manufacturing industrial and commercial blowers, industrial and commercial exhaust and ventilating fans, and attic fans, or in manufacturing dust collection and other air purification equipment for heating, ventilating and air-conditioning systems or for industrial gas cleaning systems. machinery and equipment manufacturing filters, air: furnaces, air conditioning equipment, etc. industrial and commercial fan and blower and air purification equipment manufacturing manufacture of non-domestic cooling and ventilation equipment manufacture of other general-purpose machinery manufacture of non-domestic cooling and ventilation equipmentother machinery and equipment manufacturing not elsewhere classified
# KOR: 송풍기 및 인화기  이하에 열거되지 않은 산업 및 상업용 송풍기, 산업 및 상업용 배기 및 통풍용 송풍기, 다락용 송풍기를 제조하거나, 난방, 냉방 및 환기용 시스템 또는 산업용 가스 정화 시스템을 위한 먼지 수집 및 기타 공기 정화 장비를 제조하는 경우. 기계 및 장비제조 필터, 공기: 연실, 공조설비등 산업 및 상업용 송풍기 및 인화기 및 공기정화장비 제조업 공업용 냉방, 통풍이외의 냉방 및 통풍기 제조업기타 일반목적용 기계 제조업공기조화장치 제조업공기조화장치 제조업기타 기계 및 장비 제조업 기타 분류 안된 기계 및 장비 제조업
# -----------------------------------
# ENG: agricultural chemicals, nec  the formulation and preparation of ready-to-use agricultural and household pest control chemicals, including insecticides, fungicides, and herbicides, from technical chemicals or concentrates; and the production of concentrates which require further processing before use as agricultural pesticides. this also includes manufacturing or formulating agricultural chemicals, not elsewhere classified, such as minor or trace elements and soil conditioners. agricultural chemical manufacturing agricultural chemicals, nec pesticide and other agricultural chemical manufacturing manufacture of pesticides and other agrochemical products manufacture of pesticides and other agrochemical products manufacture of pesticides and other agrochemical productspesticide manufacturing
# KOR: 농약, 기타 화학물질 제조  살충제, 살균제, 제초제 등 농약 및 가정용 해충구제용 화학물질을 기술원제나 농축액으로부터 제조하여 사용할 수 있는 상태로 조제하는 것과 농약으로 사용하기 전에 추가가공이 필요한 농축액을 생산하는 것을 말한다. 이에는 미량요소나 토양개량제 등 기타 분류되지 않은 농약의 제조나 조제도 포함된다. 농약 제조 기타 농약 제조 농약 및 기타 농약 제조업 농약 및 기타 농약 제조업 농약 및 기타 농약 제조업농약 제조업
# -----------------------------------
# ENG: construction materials, nec, nsk  the wholesale distribution of mobile homes and of construction materials, not elsewhere classified, including prefabricated buildings and glass. nonclassifiable establishments construction materials, nec other construction material merchant wholesalers nonclassifiable establishments wholesale of construction materials, hardware, plumbing and heating equipment and supplies wholesale of wood, construction materials and sanitary equipmentnonclassifiable establishments
# KOR: 건설자재, 기타, nsk  조립식 건물 및 유리를 포함한 기타 분류되지 않은 건설자재의 도매판매. 분류할 수 없는 업체 건설자재, 기타 기타 건설자재 상품중개업자 분류할 수 없는 업체 건설자재, 하드웨어, 배관 및 난방장비 및 용품 도매업 목재, 건설자재 및 위생설비 도매업분류할 수 없는 업체
# -----------------------------------
# ENG: industrial machinery and equipment  the wholesale distribution of industrial machinery and equipment, not elsewhere classified. nonclassifiable establishments industrial machinery and equipment industrial machinery and equipment merchant wholesalers nonclassifiable establishments wholesale of other machinery and equipment wholesale of other machinery, equipment and suppliesnonclassifiable establishments
# KOR: 산업기계·장비  기타 분류 안 된 산업 기계·장비의 도매업. 비주거용 건물의 건축업 비주거용 건물의 건축업 비주거용 건물의 건축업 기타 분류 안 된 산업 기계·장비의 도매업 기타 비주거용 건물의 건축업 산업 기계·장비 및 부품 도매업 기타 비주거용 건물의 건축업 산업 기계·장비 및 부품 도매업 산업 기계·장비 및 부품 도매업 기타 분류 안 된 산업 기계·장비의 도매업 기타 분류 안 된 산업 기계·장비의 도매업 산업 기계·장비 및 부품 도매업 기타 비주거용 건물의 건축업 기타 비주거용 건물의 건축업 산업 기계·장비 및 부품 도매업 기타 비주거용 건물의 건축업 기타 비주거용 건물의 건축업 산업 기계·장비 및 부품 도매업 기타 비주거용 건물의 건축업 기타 비주거용 건물의 건축업 산업 기계·장비 및 부품 도매업 기타 비주거용 건물의 건축업 기타 비주거용 건물의 건축업 산업 기계·장비 및 부품 도매업 기타 비주거용 건물의 건축업 기타 비주거용 건물의 건축업 산업 기계·장비 및 부품 도매업 기타 비주거
# -----------------------------------
# ENG: construction and mining machinery  the wholesale distribution of construction or mining cranes, excavating machinery and equipment, power shovels, road construction and maintenance machinery, tractor-mounting equipment and other specialized machinery and equipment used in the construction, mining, and logging industries. machinery wholesale construction and mining machinery, nec construction and mining (except oil well) machinery and equipment merchant wholesalers wholesale of mining, construction and civil engineering machinery wholesale of other machinery and equipment wholesale of mining, construction and civil engineering machineryagricultural and construction machinery wholesaling
# KOR: 건설 및 광업 기계  건설 또는 광업용 크레인, 굴착 기계 및 장비, 파워 삽, 도로 건설 및 유지 보수 기계, 트랙터 장착 장비 및 건설, 광업 및 벌목 산업에서 사용되는 기타 특수 기계 및 장비의 도매 유통. 기계 도매 건설 및 광업 기계, 기타 건설 및 광업 (석유 우물 제외) 기계 및 장비 상인 도매 광업, 건설 및 토목 공사 기계 도매 기타 기계 및 장비 도매 광업, 건설 및 토목 공사 기계도매 농업 및 건설 기계 도매
# -----------------------------------
# ENG: agricultural chemicals, nec  the formulation and preparation of ready-to-use agricultural and household pest control chemicals, including insecticides, fungicides, and herbicides, from technical chemicals or concentrates; and the production of concentrates which require further processing before use as agricultural pesticides. this also includes manufacturing or formulating agricultural chemicals, not elsewhere classified, such as minor or trace elements and soil conditioners. agricultural chemical manufacturing pesticides, agricultural or household pesticide and other agricultural chemical manufacturing manufacture of pesticides and other agrochemical products manufacture of pesticides and other agrochemical products manufacture of pesticides and other agrochemical productspesticide manufacturing
# KOR: 농약, 기타  살충제, 살균제, 제초제 등 농업용 및 가정용 해충구제화학물질을 기술용제 또는 농축물로부터 조제 및 제조하는 산업; 농업용 살충제로 사용하기 전에 추가적인 가공이 필요한 농축물을 생산하는 산업. 이 산업에는 미량 또는 소량 원소 및 토양개량제와 같은 기타 분류되지 않은 농약을 제조하거나 제제하는 산업도 포함된다. 농약 제조업 농약, 농업용 또는 가정용 살충제 및 기타 농약 제조업 농약 및 기타 농약 제조 농약 및 기타 농약 제조 농약 및 기타 농약 제조농약 제조업
# -----------------------------------
# ENG: paperboard mills, nsk  manufacturing paperboard, including paperboard coated on the paperboard machine, from wood pulp and other fiber pulp; and which may also manufacture converted paperboard products. paper product manufacturing paperboard mills paperboard mills manufacture of paper and paperboard manufacture of pulp, paper and paperboard manufacture of corrugated paper and paperboard and of containers of paper and paperboardpulp, paper and paperboard manufacturing
# KOR: 판지제지공장, nsk  제지기계에서 코팅된 판지를 포함하여, 제지공장에서 목재 펄프 및 기타 섬유 펄프로 판지를 제조합니다. 그리고 변환된 판지 제품도 제조할 수 있습니다. 제지제품 제조 판지제지공장 판지제지공장 제지 및 판지 제조 펄프, 제지 및 판지 제조 골판지 및 판지 및 종이 및 판지 용기 제조펄프, 제지 및 판지 제조
# -----------------------------------
# ENG: pulp mills, nsk  manufacturing pulp from wood or from other materials, such as rags, linters, wastepaper, and straw. paper product manufacturing pulp mills pulp mills manufacture of pulp manufacture of pulp, paper and paperboard manufacture of pulppulp, paper and paperboard manufacturing
# KOR: 펄프 공장, nsk  목재 또는 기타 재료, 예를 들어 넝마, 린터, 폐지 및 짚에서 펄프를 제조. 종이 제품 제조 펄프 공장 펄프 공장 펄프의 제조 펄프, 종이 및 판지의 제조 펄프, 종이 및 판지 제조
# -----------------------------------
# ENG: flavoring extracts and syrups, nec  manufacturing flavoring extracts, syrups, powders, and related products, not elsewhere classified, for soda fountain use or for the manufacture of soft drinks, and colors for bakers' and confectioners' use. food manufacturing flavoring extracts and syrups, nec flavoring syrup and concentrate manufacturing manufacture of other food products n.e.c. manufacture of other food products n.e.c. manufacture of other food products n.e.c.soft drink, cordial and syrup manufacturing
# KOR: 향료 추출물 및 시럽 제조, 기타제조업 제과용 향료 추출물, 시럽, 가루 및 관련 제품, 기타 분류되지 않은 제품을 소다 분수대 사용 또는 청량음료 제조를 위해 제조하고, 제빵사 및 제과점용 색소를 제조한다. 식품제조업 향료 추출물 및 시럽 제조, 기타제조업 향료 시럽 및 농축액 제조 기타 식품 제조 n.e.c. 기타 식품 제조 n.e.c. 기타 식품 제조 n.e.c.청량음료, 청량음료 및 시럽 제조
# -----------------------------------
# ENG: drilling oil and gas wells, nsk pt pertamina persero pertamina is a state-owned integrated energy company. it has operations across the energy value chain from upstream to downstream. its upstream operations include exploration, development and production of oil and natural gas. the company also provides upstream technology, drilling and well maintenance services; and develops geothermal energy, coal bed methane cbm and shale gas. its downstream operations include refining, marketing, trading and distribution of fuel, lubricants, liquefied petroleum gas, petrochemical products and other non-fuel products to domestic and international markets. the company has operations in malaysia, iraq, algeria, italy, france, myanmar, canada, congo, tanzania, gabon, colombia, namibia and venezuela. pertamina is headquartered in jakarta, indonesia. support activities for mining drilling oil and gas wells drilling oil and gas wells support activities for petroleum and natural gas extraction support activities for petroleum and natural gas extraction support activities for petroleum and natural gas extractionother mining support services
# KOR: 석유 및 가스정 시추 지원 활동, nsk pt pertamina persero pertamina는 국영 통합 에너지 회사입니다. 업스트림에서 다운스트림에 이르는 에너지 가치 사슬 전반에 걸쳐 사업을 진행하고 있습니다. 업스트림 사업에는 석유 및 천연가스의 탐사, 개발 및 생산이 포함됩니다. 회사는 또한 업스트림 기술, 시추 및 유정 유지 보수 서비스를 제공하며, 지열 에너지, 석탄층 메탄 cbm 및 셰일 가스를 개발합니다. 다운스트림 사업에는 연료, 윤활유, 액화 석유 가스, 석유 화학 제품 및 기타 비 연료 제품의 국내 및 국제 시장에 대한 정제, 마케팅, 거래 및 유통이 포함됩니다. 회사는 말레이시아, 이라크, 알제리, 이탈리아, 프랑스, 미얀마, 캐나다, 콩고, 탄자니아, 가봉, 콜롬비아, 나미비아 및 베네수엘라에서 사업을 진행하고 있습니다. pertamina는 인도네시아 자카르타에 본사를 두고 있습니다. 광업 시추 지원 활동 석유 및 가스정 시추 지원 활동 석유 및 천연가스 추출 지원 활동 석유 및 천연가스 추출 지원 활동 기타 광업 지원 서비스
# -----------------------------------
# ENG: petroleum refining  producing gasoline, kerosene, distillate fuel oils, residual fuel oils, and lubricants, through fractionation or straight distillation of crude oil, redistillation of unfinished petroleum derivatives, cracking or other processes. establishments of this industry also produce aliphatic and aromatic chemicals as by-products. petroleum product manufacturing gas, refinery petroleum refineries mineral oil refining manufacture of refined petroleum products manufacture of refined petroleum productspetroleum refining and petroleum fuel manufacturing
# KOR: 석유 정제  원유, 미완성 석유 유도체의 분별 증류나 직류 증류, 크래킹이나 다른 공정을 통해 가솔린, 등유, 경유, 잔사유, 윤활유 등을 생산하는 업종이다. 이 업종 소속 업체들은 부산물로 지방족 및 방향족 화학제품을 생산하기도 한다. 석유제품 제조업 가스, 정유소 석유 정제소 광물유 정제 정유제품 제조업 정제된 석유제품 제조업석유 정제 및 석유 연료 제조업
# -----------------------------------
# ENG: farm supplies, nsk  the wholesale distribution of animal feeds, fertilizers, agricultural chemicals, pesticides, seeds, and other farm supplies, except grains. nonclassifiable establishments fertilizers and agricultural chemicals farm supplies merchant wholesalers nonclassifiable establishments wholesale of agricultural raw materials and live animals wholesale of agricultural raw materials and live animalsnonclassifiable establishments
# KOR: 농자재, nsk  곡물 이외의 동물사료, 비료, 농약, 종자, 기타 농자재의 도매업. 기타 분류안된 도매업 비료 및 농약 농자재 상사 기타 분류안된 도매업 농산품원료 및 살아있는 가축 도매업 농산품원료 및 살아있는 가축도매업기타 분류안된 도매업
# -----------------------------------
# ENG: farm supplies, nsk  the wholesale distribution of animal feeds, fertilizers, agricultural chemicals, pesticides, seeds, and other farm supplies, except grains. miscellaneous wholesale fertilizer and fertilizer materials farm supplies merchant wholesalers wholesale of grain, unmanufactured tobacco, seeds and animal feeds wholesale of agricultural raw materials and live animals wholesale of agricultural raw materials and live animalsother agricultural product wholesaling
# KOR: 농기구, nsk  곡류를 제외한 동물용 사료, 비료, 농약, 종자, 기타 농기구의 도매 유통. 기타 도매 비료 및 비료 재료 농기구 상인 도매업 곡물, 가공되지 않은 담배, 종자 및 동물 사료 도매업 농작물 원재료 및 가축 도매업 농작물 원재료 및 가축기타 농산물 도매업
# -----------------------------------
# ENG: homefurnishings  the wholesale distribution of home furnishings and housewares, including antiques; china; glassware and earthenware; lamps including electric; curtains and draperies; linens and towels; and carpets, linoleum, and all other types of hard and soft surface floor coverings. home furnishings wholesale homefurnishings home furnishing merchant wholesalers wholesale of china and glassware and cleaning materials wholesale of other household goods wholesale of furniture, carpets and lighting equipmentfurniture and floor covering wholesaling
# KOR: 홈퍼니싱  골동품을 포함한 가정용 가구 및 가정용 제품의 도매 유통; 중국; 유리제품 및 도자기; 전기를 포함한 램프; 커튼 및 커튼; 리넨 및 수건; 카펫, 리놀륨 및 모든 종류의 단단하고 부드러운 표면 바닥재. 홈퍼니싱 도매 홈퍼니싱 홈퍼니싱 상품 도매업자 중국 및 유리제품 및 청소 재료 도매업자 기타 가정 용품 도매업자 가구, 카펫 및 조명 장비 도매업자 가구 및 바닥재 도매업
# -----------------------------------
# ENG: computer terminals, nsk  manufacturing computer terminals. computer and peripheral equipment manufacturing computer terminals, monitors and components computer terminal and other computer peripheral equipment manufacturing manufacture of computers and peripheral equipment manufacture of computers and peripheral equipment manufacture of computers and peripheral equipmentcomputer and electronic office equipment manufacturing
# KOR: 컴퓨터 단말기, nsk  제조 컴퓨터 단말기. 컴퓨터 및 주변기기 제조 컴퓨터 단말기, 모니터 및 부품 컴퓨터 단말기 및 기타 컴퓨터 주변기기 제조 컴퓨터 및 주변기기 제조 컴퓨터 및 주변기기 제조 컴퓨터 및 주변기기 제조컴퓨터 및 전자 사무용 기기 제조
# -----------------------------------
# ...
# -----------------------------------
# ENG: clothing: womens, childrens, and infants  the wholesale distribution of women's, children's, and infants' clothing and accessories, including hosiery, lingerie, millinery, and furs. clothing and apparel wholesale diapers women's, children's, and infants' clothing and accessories merchant wholesalers wholesale of clothing and footwear wholesale of textiles, clothing and footwear wholesale of clothing and footwearclothing and footwear wholesaling
# KOR: 의류: 여성용, 아동용, 유아용  여성용, 아동용, 유아용 의류 및 액세서리, 호시리, 란제리, 모자, 모피 등의 도매 유통. 의류 및 의류 도매 기저귀 여성용, 아동용, 유아용 의류 및 액세서리 상품 도매업 의류 및 신발 도매업 의류 및 신발 도매업의류 및 신발 도매업
# -----------------------------------
# ENG: cane sugar refining  refining purchased raw cane sugar and sugar syrup. food manufacturing refined cane sugar, from purchased raw sugar or syrup cane sugar manufacturing manufacture of sugar manufacture of sugar manufacture of sugarsugar manufacturing
# KOR: 사탕수수 정제  정제 구입한 원료 사탕수수와 설탕 시럽. 식품 제조 정제 사탕수수, 구입된 원료 설탕 또는 시럽 사탕수수 제조 제조 설탕 제조 설탕 제조 사탕수수 제조
# -----------------------------------
# ENG: truck and bus bodies, nsk  manufacturing truck and bus bodies and cabs for sale separately or for assembly on purchased chassis, or in assembling truck and bus bodies on purchased chassis. motor vehicle parts manufacturing truck and bus bodies motor vehicle body manufacturing manufacture of bodies (coachwork) for motor vehicles (except caravans) manufacture of bodies (coachwork) for motor vehicles; manufacture of trailers and semi-trailers manufacture of bodies (coachwork) for motor vehicles; manufacture of trailers and semi-trailersmotor vehicle and motor vehicle part manufacturing
# KOR: 트럭과 버스 차체, nsk  제조 트럭과 버스 차체와 캡을 별도로 또는 구입한 차대에 조립하기 위해 판매하거나, 구입한 차대에 트럭과 버스 차체를 조립하는 것. 자동차부품 제조 트럭과 버스 차체 자동차 차체 제조 자동차(caravans제외) 차체(coachwork) 제조 자동차(caravans제외) 차체(coachwork) 제조; 트레일러와 세미트레일러 제조 자동차(caravans제외) 차체(coachwork) 제조; 트레일러와 세미트레일러 제조자동차와 자동차부품 제조
# -----------------------------------
# ENG: broadwoven fabric mills, wool  weaving fabrics more than 12 inches 30.48 centimeters in width, wholly or chiefly by weight of wool, mohair, or similar animal fibers; dyeing and finishing all woven wool fabrics or dyeing wool, tops, or yarn; and those shrinking and sponging wool goods for the trade. textile manufacturing dyeing and finishing: wool or similar fibers broadwoven fabric mills weaving of textiles weaving of textiles weaving of textilesnatural textile manufacturing
# KOR: 넓은 직물 공장, 양모  폭이 12 인치 30.48 센티미터 이상인 직물을 직조하는 양모, 모헤어 또는 유사한 동물 섬유의 중량 또는 주로; 모든 직조 된 양모 직물의 염색 및 마무리 또는 염색 양모, 톱 또는 실; 그리고 그 수축 및 스폰지 양모 상품을위한 무역. 섬유 제조 염색 및 마무리 : 양모 또는 유사한 섬유 넓은 직물 공장 직물 직조 직물 직조 직물직물 직조천연 섬유 제조
# -----------------------------------
# ENG: blowers and fans  manufacturing industrial and commercial blowers, industrial and commercial exhaust and ventilating fans, and attic fans, or in manufacturing dust collection and other air purification equipment for heating, ventilating and air-conditioning systems or for industrial gas cleaning systems. machinery and equipment manufacturing exhaust fans: industrial or commercial industrial and commercial fan and blower and air purification equipment manufacturing manufacture of non-domestic cooling and ventilation equipment manufacture of other general-purpose machinery manufacture of non-domestic cooling and ventilation equipmentother machinery and equipment manufacturing not elsewhere classified
# KOR: 송풍기 및 팬 제조산업 및 상업용 송풍기, 산업 및 상업용 배기 및 환기 팬, 다락방 팬을 제조하거나, 난방, 환기 및 공기조화 시스템 또는 산업용 가스정화 시스템을 위한 집진 및 기타 공기정화 장비를 제조. 기계류 및 장비 제조 배기 팬: 산업용 또는 상업용 산업 및 상업용 팬 및 송풍기 및 공기정화 장비 제조 비주거용 냉각 및 환기 장비 제조 기타 일반 목적용 기계류 제조 비주거용 냉각 및 환기 장비제조기타 기계 및 장비 제조 n.e.c.
# -----------------------------------
# ENG: nonclassifiable establishments  the wholesale distribution of electronic parts and electronic communications equipment, not elsewhere classified, such as telephone and telegraphic equipment; radio and television broadcasting and communications equipment; and intercommunications equipment. nonclassifiable establishments electronic parts and equipment, nec other electronic parts and equipment merchant wholesalers nonclassifiable establishments wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and partsnonclassifiable establishments
# KOR: 분류되지 않은 업체  전자부품 및 전자통신장비의 도매유통, 기타 분류 안 된 업체, 예컨대 전화 및 전신 기기; 라디오 및 텔레비전 방송 및 통신장비; 상호통신 장비. 분류되지 않은 업체 전자부품 및 장비, NEC 기타 전자부품 및 장비 상품 도매업 분류되지 않은 업체 전자 및 통신장비 및 부품 도매업 전자 및 통신장비 및 부품 도매업분류되지 않은 업체
# -----------------------------------
# ENG: cement, hydraulic, nsk  manufacturing hydraulic cement, including portland, natural, masonry, and pozzolana cements. cement and concrete product manufacturing natural cement cement manufacturing manufacture of cement manufacture of cement, lime and plaster manufacture of cementcement and lime manufacturing
# KOR: 시멘트, 수화, nsk  포틀랜드, 천연, 석조 및 포졸라나 시멘트를 포함한 수화 시멘트 제조. 시멘트 및 콘크리트 제품 제조 천연 시멘트 시멘트 제조 시멘트 제조, 석회 및 석고 제조 시멘트 제조시멘트 및 석회 제조
# -----------------------------------
# ENG: industrial supplies, nsk  the wholesale distribution of industrial supplies, not elsewhere classified. machinery wholesale welding supplies industrial supplies merchant wholesalers wholesale of other machinery and equipment wholesale of other machinery and equipment wholesale of other intermediate productsother specialised industrial machinery and equipment wholesaling
# KOR: 산업용 공급품, nsk  기타 분류되지 않은 산업용 공급품 도매. 기계 도매 용접 용품 산업용 공급품 상인 도매 기타 기계 및 장비 도매 기타 기계 및 장비 도매 기타 중간 제품기타 특수 산업용 기계 및 장비 도매
# -----------------------------------
# ENG: freight transportation arrangement, nsk  furnishing shipping information and acting as agents in arranging transportation for freight and cargo. also included in this industry are freight forwarders which undertake the transportation of goods from the shippers to receivers for a charge covering the entire transportation, and, in turn, make use of the services of other transportation establishments as instrumentalities in effecting delivery. road transportation services customs clearance of freight freight transportation arrangement other transportation support activities other transportation support activities other transportation support activitiesother transport support services not elsewhere classified
# KOR: 화물운송 주선업, nsk  화물의 운송을 주선하고 운송에 관한 정보를 제공하는 업무를 수행한다. 또한 이 산업에는 화주로부터 수하인에게 화물의 운송을 일괄적으로 담당하는 화물운송 주선업이 포함되며, 이에 따라 운송의 효과를 위하여 다른 운송업소의 서비스를 이용한다. 도로교통 서비스의 화물 운송 주선업 기타 운송지원 활동 기타 운송지원 활동기타 운송 지원 활동기타 운송 지원 활동기타 운송지원 서비스 기타에 포함되지 않은
# -----------------------------------
# ENG: nonclassifiable establishments  selling primarily lumber, or lumber and a general line of building materials, to the general public. while these establishments may sell primarily to construction contractors, they are known as retail in the trade. the lumber which they sell may include rough and dressed lumber, flooring, molding, doors, sashes, frames, and other millwork. the building materials may include roofing, siding, shingles, wallboard, paint, brick, tile, cement, sand, gravel, and other building materials and supplies. hardware is often an important line sold by retail lumber and building materials dealers. home and garden retail lumber and other building materials home centers retail sale of hardware, paints and glass in specialised stores retail sale of hardware, paints and glass in specialized stores retail sale of hardware, paints and glass in specialised storeshardware and building supplies retailing
# KOR: 목재를 주로 판매하지만, 일반 대중에게 판매되는 비분류 사업체. 이러한 사업체는 주로 건설업자에게 판매되지만, 업계에서는 소매업으로 알려져 있습니다. 판매하는 목재에는 거친 목재와 가공된 목재, 바닥재, 몰딩, 문, 창문, 프레임 및 기타 목재 제품이 포함될 수 있습니다. 건축 자재에는 지붕, 사이딩, 지붕판, 벽판, 페인트, 벽돌, 타일, 시멘트, 모래, 자갈 및 기타 건축 자재 및 용품이 포함될 수 있습니다. 하드웨어는 소매 목재 및 건축 자재 판매업자가 판매하는 중요한 제품군입니다. 가정 및 정원 소매 목재 및 기타 건축 자재 홈 센터 하드웨어, 페인트 및 유리를 전문으로 판매하는 소매업 하드웨어, 페인트 및 유리를 전문으로 판매하는 소매업 하드웨어 및 건축 자재 소매업
# -----------------------------------
# ENG: adhesives and sealants, nsk  manufacturing industrial and household adhesives, glues, caulking compounds, sealants, and linoleum, tile, and rubber cements from vegetable, animal, or synthetic plastics materials, purchased or produced in the same establishment. nonclassifiable establishments adhesives adhesive manufacturing nonclassifiable establishments manufacture of other chemical products n.e.c. manufacture of gluesnonclassifiable establishments
# KOR: 접착제 및 밀봉제, nsk  제조 산업 및 가정용 접착제, 접착제, 코킹 화합물, 밀봉제, 리놀륨, 타일 및 고무 시멘트, 식물성, 동물성 또는 합성 플라스틱 재료에서 구입되거나 동일한 시설에서 생산됩니다. 비분류 시설 접착제 접착제 제조 비분류 시설 기타 화학 제품 n.e.c. 제조 접착제비분류 시설
# -----------------------------------
# ENG: homefurnishings  the wholesale distribution of home furnishings and housewares, including antiques; china; glassware and earthenware; lamps including electric; curtains and draperies; linens and towels; and carpets, linoleum, and all other types of hard and soft surface floor coverings. home furnishings wholesale stainless steel flatware home furnishing merchant wholesalers wholesale of china and glassware and cleaning materials wholesale of other household goods wholesale of furniture, carpets and lighting equipmentfurniture and floor covering wholesaling
# KOR: homefurnishings  가정용 가구와 생활용품을 도매로 유통하는 것으로, 골동품; 도자기; 유리제품과 토기; 전기를 포함한 램프; 커튼과 장막; 리넨과 타월; 및 카펫, 리놀륨, 그리고 모든 다른 종류의 단단한 표면과 부드러운 표면의 바닥재를 유통한다. 가정용 가구 도매 스테인리스 플랫웨어 가정용 가구 상인 도매업자 도자기 및 유리제품과 청소용품 도매업자 다른 가정용 물품 도매업자 가구, 카펫과 조명 장비 도매업자가구 및 바닥재 도매업자
# -----------------------------------
# ENG: drugs, proprietaries, and sundries  the wholesale distribution of prescription drugs, proprietary drugs, druggists' sundries, and toiletries. nonclassifiable establishments animal medicines drugs and druggists' sundries merchant wholesalers nonclassifiable establishments wholesale of other household goods wholesale of pharmaceutical goodsnonclassifiable establishments
# KOR: 의약품, 변종상품 및 일용품  증감가공한 의약품, 변종상품, 약종상일용품 및 세면용 일용품의 도매유통업. 분류할 수 없는 업소 동물의약품 의약품 및 약종상일용품상 상품도매업 분류할 수 없는 업소 기타 가정용품 도매업 의약품 도매업 분류할 수 없는 업소
# -----------------------------------
# ENG: warm air heating and air conditioning  the wholesale distribution of warm air heating and air-conditioning equipment and supplies. construction and hardware materials wholesale compressors, air conditioning warm air heating and air-conditioning equipment and supplies merchant wholesalers wholesale of other machinery and equipment wholesale of construction materials, hardware, plumbing and heating equipment and supplies wholesale of hardware, plumbing and heating equipment and suppliesother electrical and electronic goods wholesaling
# KOR: 온풍 난방 및 공조  온풍 난방 및 공조 장비 및 용품의 도매 유통. 건설 및 하드웨어 재료 도매 압축기, 공조 온풍 난방 및 공조 장비 및 용품 상품 도매 기타 기계 및 장비 도매 건설 자재, 하드웨어, 배관 및 난방 장비 및 용품 도매 하드웨어, 배관 및 난방 장비 및 용품기타 전기 및 전자 제품 도매
# -----------------------------------
# ENG: automobiles and other motor vehicles, nsk  the wholesale distribution of new and used passenger automobiles, trucks, trailers, and other motor vehicles, including motorcycles, motor homes, and snowmobiles. motor vehicle wholesale motorcycles automobile and other motor vehicle merchant wholesalers sale of motor vehicles sale of motor vehicles sale of motor vehiclesmotor vehicle and motor vehicle parts wholesaling
# KOR: 자동차 및 기타 자동차, nsk  자동차, 트럭, 트레일러 및 모터 홈 및 스노모빌을 포함한 기타 자동차의 새 제품 및 중고 제품 도매 유통. 자동차 도매 오토바이 자동차 및 기타 자동차 상품 도매업 자동차 판매 자동차 판매 자동차 판매자동차 및 자동차 부품 도매업
# -----------------------------------
# ENG: industrial machinery and equipment  the wholesale distribution of industrial machinery and equipment, not elsewhere classified. nonclassifiable establishments drilling bits industrial machinery and equipment merchant wholesalers nonclassifiable establishments wholesale of other machinery and equipment wholesale of other machinery, equipment and suppliesnonclassifiable establishments
# KOR: 산업기계 및 장비  기타 분류되지 않은 산업기계 및 장비의 도매 판매. 분류되지 않은 업체들 드릴링비트 산업기계 및 장비 상품중개인 분류되지 않은 업체들 기타 기계 및 장비 도매기타 기계, 장비 및 용품도매분류되지 않은 업체들
# -----------------------------------
# ENG: printing and writing paper, nsk  the wholesale distribution of printing and writing paper, including envelope paper; fine paper; and groundwood paper. paper wholesale fine paper printing and writing paper merchant wholesalers wholesale of other intermediate products wholesale of waste and scrap and other products n.e.c. wholesale of other machinery, equipment and suppliespaper product wholesaling
# KOR: 인쇄 및 필기 용지, nsk 봉투 용지를 포함한 인쇄 및 필기 용지, 고급 용지 및 지소 용지의 도매 유통. 용지 도매 고급 용지 인쇄 및 필기 용지 상인 도매 기타 중간 제품 도매 폐기물 및 스크랩 및 기타 제품 n.e.c. 도매 기타 기계, 장비 및 용품종이 제품 도매
# -----------------------------------
# ENG: leather and sheep-lined clothing  manufacturing leather and sheep-lined clothing. nonclassifiable establishments garments, leather other cut and sew apparel manufacturing nonclassifiable establishments manufacture of wearing apparel, except fur apparel manufacture of leather clothesnonclassifiable establishments
# KOR: 피혁 및 양피 가공 의류  제조 가죽 및 양피 가공 의류. 비분류 업체 의류, 가죽 기타 재단 및 봉제 의복 제조업 비분류 업체 모피제품을 제외한 착용하는 의복 제조업가죽옷제조업비분류업체
# -----------------------------------
# ENG: electronic parts and equipment, nec, nsk  the wholesale distribution of electronic parts and electronic communications equipment, not elsewhere classified, such as telephone and telegraphic equipment; radio and television broadcasting and communications equipment; and intercommunications equipment. electronics wholesale electronic parts other electronic parts and equipment merchant wholesalers wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and parts wholesale of electronic and telecommunications equipment and partsother electrical and electronic goods wholesaling
# KOR: 전자부품 및 장비, nec, nsk  전자부품 및 전자통신 장비, 기타 분류되지 않은 상품(전화 및 전신 장비; 라디오 및 텔레비전 방송 및 통신 장비; 및 인터커뮤니케이션 장비)의 도매 유통. 전자제품 도매 전자부품 기타 전자부품 및 장비 도매업 전자 및 통신 장비 및 부품 도매업 전자 및 통신 장비 및 부품 도매업기타 전기 및 전자 제품 도매업
# -----------------------------------
# ENG: bottled and canned soft drinks, nsk  manufacturing soft drinks and carbonated waters. beverage manufacturing carbonated beverages, nonalcoholic: pkged. in cans, bottles soft drink manufacturing manufacture of soft drinks; production of mineral waters and other bottled waters manufacture of soft drinks; production of mineral waters and other bottled waters manufacture of soft drinks; production of mineral waters and other bottled waterssoft drink, cordial and syrup manufacturing
# KOR: 병 및 캔에 담긴 탄산음료, nsk  제조 음료 및 탄산수. 음료 제조 탄산음료, 무알콜: 캔, 병에 담긴 소프트 드링크 제조 소프트 드링크 제조; 미네랄 워터 및 기타 병에 담긴 물 제조 소프트 드링크 제조; 미네랄 워터 및 기타 병에 담긴 물 제조 소프트 드링크 제조; 미네랄 워터 및 기타 병에 담긴 물 제조소프트 드링크, 코디얼 및 시럽 제조
# -----------------------------------
# ENG: blast furnaces and steel mills, nsk  manufacturing hot metal, pig iron, and silvery pig iron from iron ore and iron and steel scrap; converting pig iron, scrap iron, and scrap steel into steel; and in hot-rolling iron and steel into basic shapes, such as plates, sheets, strips, rods, bars, and tubing. merchant blast furnaces and by-product or beehive coke ovens are also included in this industry. metal products manufacturing tinplate iron and steel mills and ferroalloy manufacturing manufacture of basic iron and steel and of ferro-alloys manufacture of basic iron and steel manufacture of basic iron and steel and of ferro-alloysiron smelting and steel manufacturing
# KOR: 제철 및 제강공장, nsk  광석 및 철스크랩으로부터 고철, 선철 및 은백색 선철을 제조하고, 선철, 고철 및 강철스크랩을 강철로 전로처리하며, 철 및 강철을 열간압연하여 판, 시트, 스트립, 봉, 막대 및 튜브 등의 기본형태로 가공한다. 이 산업에는 상철 및 부생코크스 공장이 포함된다. 금속제품 제조 주석도금 철 및 강철 공장과 페로합금 제조업은 기본철강 및 페로합금의 제조를 의미한다. 기본철강 및 페로합금의 제조철강제조
